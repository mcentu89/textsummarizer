# %% [markdown]
# ### Data Ingestion Module

# %%
introduction_hugging_face = """
¡Hola, chicos!

Así que ahora vamos a poner en marcha un nuevo proyecto de PNL de extremo a extremo con la ayuda de modelos de caras abrazadas.

Ahora bien, si no conoces Hugging Face, es una empresa increíble en la que tienes varios tipos diferentes de

modelos que probablemente puedas integrar en tu proyecto y puedes implementar una solución

integral.

Y no sólo eso, hugging face le proporciona puntos finales de API de hugging face.

Es realmente increíble para, uh, aplicaciones de IA generativa porque todos los modelos de código abierto están disponibles en

la cara de abrazo.

La mayoría de las empresas que proponen específicamente modelos de código abierto, los integran con cara

de abrazo.

Si hay algún modelo específico, ¿cómo se integra en las soluciones integrales

de los proyectos y cómo se aplica?

Ok, entonces dentro de esto como si probablemente fueras a Cara de abrazo. co, por favor, siga adelante y regístrese.

Y espero que si usted tiene algún conocimiento básico sobre el aprendizaje automático, creo que debe haber oído hablar

de abrazar la cara en sí.

Ya me he registrado y esta es mi cuenta.

Y aquí podrás ver que una vez que siga adelante y haga clic en modelos.

Bien.

Así que Hugging Face te ofrece muchos modelos diferentes, como el multimodal.

Te proporciona modelos relacionados con la visión por ordenador que cualquiera puede utilizar específicamente.

Ya sabes, como estimación de profundidad, clasificación de imágenes, detección de objetos, segmentación de imágenes, conversión de texto

en imagen, cualquier cosa por el estilo.

En cuanto al procesamiento del lenguaje natural, se pueden realizar tareas como la clasificación

de textos, la clasificación de tokens, la respuesta a preguntas o la clasificación de cero disparos.

En nuestro proyecto, básicamente vamos a implementar un resumen de texto uh, caso de uso.

Sabes que vamos a resolverlo.

Vale, hablaré más de ello.

Pero también hay modelos relacionados con el audio, como texto a voz, texto a audio y audio

a audio.

Y luego también tienes algo relacionado con el aprendizaje automático, como la clasificación tabular o los modelos de

regresión.

Y no sólo eso, también tenemos el aprendizaje automático de grafos y de refuerzo.

Así que un gran número abundante de bibliotecas están básicamente presentes en la cara de abrazo.

Uh, y usted puede utilizar cualquiera de ellos, como he dicho en este módulo en particular, uh, como en este proyecto,

vamos a implementar un resumen de texto.

Y aquí podrás ver que si sigo adelante y hago clic en Resumen de Texto aquí

podrás ver varios modelos en resumen de texto.

De acuerdo.

Uh, ahora lo que voy a hacer es que usted puede elegir cualquier modelo de resumen de texto por aquí y usted puede utilizar específicamente.

De acuerdo.

Y trataré de mostrarte que de una manera genérica probablemente puedas integrarlos.

De modo que si hago una integración con un modelo cualquiera, creo que para todos los demás modelos, debería

poder utilizarlo.

De acuerdo.

Así que vamos a seleccionar uno de ellos bien.

Cualquiera que voy a tratar de decir Google Big Bird Pegasus palma grande.

Así que si probablemente te muestro sólo un ejemplo, digamos Facebook bird, CNN, Pegasus, CNN, Daily Mail, vamos a seguir

adelante y comprobar este modelo de resumen.

Así que aquí podrás ver que esto es básicamente proporcionado por Google.

Uh de nuevo cualquiera puede usar esto específicamente.

Y uh por aquí sólo para probablemente uh, este modelo no tiene suficiente actividad para ser desplegado a la inferencia API Serverlessly

aumenta su visibilidad social y comprobar de nuevo más tarde.

O desplegar.

De acuerdo.

No pasa nada.

No tenemos que preocuparnos por esto.

Uh, aquí, usted será capaz de ver que, uh, alguna información sobre el modelo se da específicamente.

Permítanme seguir adelante y recargar esto.

Bien, aquí podrás verlo.

Entrenamos un modelo con relaciones de frases gap de muestra tanto en C4 como en noticias enormes.

Así que estos son todos los conjuntos de datos específicos que se utilizan para entrenar este modelo en particular.

Se entrena en C4.

Y la enorme mezcla de datos de noticias se pondera por el número de ejemplos entrenados a partir de 1. 5 millones en lugar de

500 K.

Ya sabes, y toda la información sobre este modelo en particular se da por aquí.

De acuerdo.

Del mismo modo, puedes seguir adelante y comprobar otros modelos como, por ejemplo, el de resumen de texto de Falcon AI.

También se puede ver aquí y uh, aquí.

Creo que había algunos ejemplos también que se dará, pero no sé por qué no se está mostrando

aquí de todos modos, pero creo que deberíamos ser capaces de ver en algunos otros, eh, modelos en sí.

De acuerdo.

Así que este es también uno más, uh, modelo como, uh, texto Falcon.

I halcones I resumen de texto, y esto no es más que un pequeño T5 afinado.

Se trata de una variante del modelo de transformación T5 y toda la información se da específicamente por encima.

He aquí algunos ejemplos al respecto.

Esto también se da donde se puede utilizar directamente este modelo en particular y se puede hacer el resumen.

Ok, uh, pero mi resumen que voy a hacer en realidad será afinando estos modelos específicos.

De acuerdo.

Así que tomemos cualquier modelo como tal.

Veamos uno más de acuerdo.

Digamos que Google Big Bird Pegasus grande grande.

Tomaremos este modelo específico.

Y eh, ya sabes, y aquí también podrás ver que básicamente se da alguna información sobre el

modelo.

Ahora bien, ¿qué significa básicamente resumir un texto?

De acuerdo.

Así que déjame hacer una cosa.

Permítanme ir por delante y abrir este sitio web en particular que se llama como bot fresco. com.

De acuerdo.

Y aquí hay muchas opciones.

Digamos corrector gramatical.

Comprobador de plagio.

Hay algo que se llama resumen de texto.

Ahora lo que voy a hacer es escribir una historia.

Así que busquemos alguna historia.

Y uh probablemente iré a mi ChatGPT y pediré una historia.

Así que la historia de un león y un rey.

De acuerdo, sé que no podrás ver mi ChatGPT, así que seguiré adelante y probablemente, hayas generado

una historia específica.

Lo pegaré aquí.

De acuerdo.

Así que déjame hacer una cosa.

Así que aquí tengo algunas historias.

De acuerdo.

Esta es mi historia.

Intentaré resumir toda esta historia.

De acuerdo.

Así que intentaremos resumirlo aquí.

Usted puede ver una historia está allí érase una vez en el Reino Nestlé enclavado entre vastos bosques y

así y así.

Voy a tratar de resumirlo y se puede ver palabras clave seleccionadas también se da.

De acuerdo.

Así que una vez que resuma específicamente haga clic en resumir.

Aquí obtendrá una versión resumida de este texto en particular o de esta frase en particular.

Bien.

Y aquí se puede ver que se trataba de una sentencia muy larga.

Y aquí tienes como una versión resumida de todo este texto.

Y eso es lo que vamos a aplicar concretamente.

Este proyecto será muy importante porque la mejor parte de esto.

Bien.

Digamos que si estoy usando este Pegasus, CNN, Daily Mail cómo integrar correctamente con la ayuda de Transformers, ¿verdad?

Porque en la cara de abrazo tienes algo llamado como Transformers, ¿verdad?

E internamente también utilizará PyTorch.

Así que usaremos esto.

Y para usar este modelo.

Bien.

Si yo probablemente seguir adelante y haga clic aquí, utilice este modelo y voy a hacer clic en Transformers.

Estos son algunos de los códigos que se dan a la derecha.

Y cómo utilizar este código en particular.

En un proyecto integral sobre el que hablaré.

Bien.

Así que eh, vamos a seguir adelante y utilizar este modelo específico en sí.

Así que vamos a seleccionar cualquiera de ellos.

Lo que también puedes hacer es que después de hacer esto, puedes probarlo con cualquier otro modelo.

Bien.

Y probablemente tú puedas hacer lo mismo.

Y será genérico.

Será genérico para todos los modelos de código abierto, eh, para todos los modelos que probablemente

está presente en abrazar la cara, eh, porque todos los pasos métodos se da básicamente.

Y abrazando la cara es, eh, como esta biblioteca transformador se crea de tal manera que, eh, todos los métodos

genéricos de probablemente cargar un modelo específico, que auto tokenizer, um, ya sabes, cómo cargar probablemente

el modelo con respecto a punto de control, cómo hacer probablemente el ajuste fino.

Todo será similar a todo este tipo de modelos en sí.

Bien.

Así que sí, esto fue sólo una introducción de este video en particular.

Este es el tipo de tarea que voy a crear, y vamos a tratar de crear un proyecto de extremo a extremo en el que seguimos una técnicas de ingestión

de datos, porque también vamos a considerar algunos conjunto de datos, ya sabes, así que en la cara de abrazo

modelo, a la derecha.

Si usted probablemente ve que hay algún tipo de conjuntos de datos.

Además, ahora mismo hay un gran número de conjuntos de datos.

Son como conjuntos de datos anotados.

Y para cada tipo de enunciado de problema diferente que va a obtener este conjunto de datos en particular voy

a utilizar un conjunto de datos que se llama como Samson supongo.

Así que este conjunto de datos Samson será específicamente allí.

Intentaremos utilizarlos y hablaré más del conjunto de datos.

Y también veremos los datos.

Qué es exactamente.

Ya sabes, porque vamos a afinar este modelo concreto e intentaremos integrarlo en nuestro proyecto de

principio a fin.

Así que esto era sólo una introducción, como lo que probablemente vamos a hacer con este proyecto específico.

Espero que le guste este vídeo en particular.

Ahora, en el siguiente vídeo, vamos a empezar a construir nuestro proyecto.

Um, así que sí, te veré en el próximo video.

Gracias.
"""

# %%
github_repo_and_project_structure_set_up = """
Hola, chicos.

Así que ahora vamos a iniciar la ejecución de nuestro proyecto.

Ahora en este video en particular voy a estar discutiendo acerca de cómo configurar su repositorio de GitHub.

Junto con eso, también seguiremos adelante con una estructura de proyecto que será adecuada para este proyecto en particular.

De acuerdo, hablaré de ambos en este vídeo en concreto.

Así que vamos a ir a nuestra ubicación de la carpeta donde estamos creando todos los proyectos de aquí.

Así que voy a seguir adelante y probablemente crear una carpeta.

Y digamos que voy a escribir Summarizer.

De acuerdo.

Así que este será básicamente el nombre de mi proyecto Summarizer.

De acuerdo.

Y dentro de esto voy a seguir adelante y abrir mi símbolo del sistema.

Y para esto también vamos a utilizar el código VS bien.

Así que ahora permítanme seguir adelante y escribir código punto y mi código VS debe abrirlo.

Bien.

Así que este es mi código VS que vamos a trabajar específicamente bien.

Ahora, como he dicho eh, en primer lugar, lo que básicamente vamos a hacer es que voy a seguir adelante y crear nuestro

terminal.

Así que para eso, voy a seguir adelante y abrir esto.

Y antes de abrir, antes de crear el terminal.

Así que lo que realmente quiero hacer es que vamos a seguir adelante y crear nuestro GitHub.

De acuerdo.

Así que para esto voy a ir a mi navegador y voy a seguir adelante y abrir mi github. com okay.

Y vamos a crear mis repositorios.

Así que voy a hacer clic en su repositorio.

Haré clic en nuevo.

Y esto será básicamente mi texto o Summarizer texto.

De acuerdo.

Así que este será básicamente mi resumidor de texto.

Aquí lo mantendré como privado.

Vamos a seguir adelante y no añadir ninguna.

Gitignore en este momento voy a tratar de añadir un archivo readme y voy a elegir una licencia.

Licencia pública general aceptable.

Una vez hecho esto vamos a crear el repositorio.

Así que una vez que crear el repositorio en primer lugar sólo seguir adelante y copiar esto.

De acuerdo.

Copie esta ruta en particular.

Ahora voy a volver de nuevo a mi carpeta.

Uh, abrimos nuestro código VS creando esta carpeta en particular que es summarizer.

Voy a cerrar este código VS.

Déjame borrar esta carpeta en particular y déjame clonarla directamente desde aquí.

Así que toda la carpeta que usted será capaz de ver, a la derecha.
"""

# %%
loggin_and_utils_commmon_functionalities = """
Hola, chicos.

Así que ahora vamos a seguir adelante e implementar nuestras funcionalidades de registro.

Y luego también vamos a seguir adelante y definir nuestras utilidades funcionalidades comunes que se va a utilizar en este

proyecto específico.

Así que voy a ir a mi carpeta de origen.

Y aquí ya hemos creado nuestra carpeta de registro dentro de Summarizer texto.

Así que vamos a hacer clic aquí y vamos a seguir adelante y abrir nuestra init subrayado py bien.

Ahora vamos a implementar nuestras funcionalidades básicas de registro.

Esta será nuestra funcionalidad de registro personalizada.

Así que en primer lugar permítanme seguir adelante e importar OS.

Junto con esto vamos a seguir adelante e importar sis.

Y también vamos a importar el registro de acuerdo.

Ahora bien, si usted ha visto uh o si usted sabe Python en este momento con respecto a las funcionalidades de registro, hay tres principales cosas importantes

que usted realmente necesita para seguir adelante y escribir.

De acuerdo.

Uno es lo que debería ser su directorio de registro.

Así que en primer lugar voy a seguir adelante y crear mi directorio de registro bien.

Así que vamos a seguir adelante y crear mi directorio log d I r log.

Digamos que mi directorio de logs no es más que logs que deberían crearse desde la raíz.

De acuerdo.

¿Con qué nombre?

Ya sabes, como, debe haber alguna cadena que debe definirse correctamente cuando estamos definiendo nuestros registros.

Bien.

Y esa cadena debe tener algún formato.

Así que vamos a seguir adelante y definir nuestra cadena de aquí bien.

Así que esto básicamente tendrá nuestro módulo de nombre de nivel de tiempo en el que el código específicamente en qué archivo se está ejecutando.

Y luego el mensaje que realmente queremos mostrar con respecto a los registros.

De acuerdo.

Entonces, una vez que tenemos nuestro directorio de registro y la cadena de registro, ahora es el momento de seguir adelante y crear nuestra

ruta de archivo de registro.

Así que lo que vamos a hacer es que vamos a crear un archivo que es como uh logs punto log.

Voy a seguir adelante y escribir registros continuos dot log.

Y luego voy a seguir adelante y crear mi OS punto make make dir directorio.

Y vamos a tomar este directorio de registro en particular que hemos creado.

De acuerdo.

Junto con esto voy a seguir adelante y escribir existe okay es igual a true.

Eso significa básicamente que si ese directorio ya existe.

No voy a seguir adelante y crearlo de nuevo.

Vale, esto es una cosa.

Y la segunda cosa es que seguimos adelante y establecer nuestra configuración básica.

De acuerdo.

Esta es mi configuración básica.

Bien.

Así que logging dot basic config podrás ver que estoy escribiendo Logging. información.

Mi formato será básicamente este logging str.

Y hay dos manipuladores que hemos utilizado.

Uno es para el manejador de archivos donde estamos escribiendo todos los detalles en nuestra ruta de archivo de registro.

Y también hay stream handler que mostrará todos los registros en mi terminal de salida.

De acuerdo.

Así que esto es con respecto a su derecho de excepción personalizado.

Lo siento.

Derecho de registro personalizado.

Básicamente lo hemos manejado.

Ahora lo siguiente que vamos a hacer rápidamente es que voy a seguir adelante y abrir mi principal. archivo py.

Y vamos a seguir adelante y probarlo bien.

Así que para el registro de lo que voy a hacer, voy a decir de src punto uh resumidor de texto voy a lo siento punto de registro.

Voy a seguir adelante e importar logger.

Bien.

Y una vez creo que es más largo.

Veamos por aquí.

De acuerdo.

Probablemente tengo que seguir adelante y definir mi registrador también por aquí.

Así que seguiré escribiendo.

Logger es igual a punto de registro.

Y aquí usaré un registrador get.

Bien.

Y esto será básicamente mi Summarizer logger.

De acuerdo.

Voy a seguir adelante y definir esto.

Así que este registrador vamos a utilizar con esta configuración derecha.

Así que volveré a mi principal. py.

Y ahora tengo este logger voy a seguir adelante y escribir logger. información.

De acuerdo.

Y aquí voy a decir hey uh registro se implementa bien.

Voy a seguir adelante y escribir algo de información.

Ahora vamos a seguir adelante y probar esto y ver si está funcionando bien o no está bien.

Así que ahora lo que voy a hacer voy a abrir mi terminal de acuerdo.

Y aquí lo que voy a hacer, sólo tienes que estar en el mismo entorno V y V bien.

Y luego voy a seguir adelante y crear uh ejecutar python principal. py.

Así que aquí se puede ver que estoy recibiendo esta información en particular.

Esta es mi fecha hora, mi información y qué archivo de mi código se está ejecutando y lo que es el mensaje que estoy mostrando en

realidad ¿verdad?

El registro se implementa ahora cuando estamos haciendo esto también a la derecha, usted también será capaz

de ver que debe haber una carpeta de registros que se crea y no es más que registro continuo.

Así que vamos a ver esto con el registro continuo básicamente se está creando allí o no.

En mi opinión. py puedes ver que mi registro continuo se está creando básicamente ¿correcto?

Así que dentro de este podrás ver todos los mensajes de los registros.

De acuerdo.

Así que nuestra funcionalidad de registro personalizado se ha implementado.

Así que estamos bien con esto.

Ahora lo siguiente será que vamos a seguir adelante y ver cuáles son las funcionalidades comunes que realmente queremos

utilizar.

Así que dentro de las utilidades habrá algo llamado como común. py.

Ahora dentro de este común. py.

Como he dicho que son, vamos a utilizar algunos importantes eh, funcionalidades.

De acuerdo.

Uno es cómo leer el archivo YAML y todo eso.

Y para ello, eh, voy a seguir adelante y la importación de importación OS.

Entonces vamos a utilizar la excepción de la propia caja.

Bien.

Así que excepciones de punto de caja.

Voy a seguir adelante e importar mi error de valor de la caja bien.

Entonces voy a seguir adelante e importar YAML.

Así que esto es básicamente para el manejo de la excepción uh caja voy a hablar de ello cuando probablemente seguir adelante.

Sabes cuando te muestro múltiples ejemplos ok.

Um, como cuando estoy haciendo la codificación en ese momento, voy a tratar de mostrar a usted.

Bien.

A continuación, voy a seguir adelante y escribir desde src punto de texto Summarizer punto de registro de acuerdo.

Logging import logger.

Ok entonces uh voy a seguir adelante y usar esta anotación ensure from ensure import ensure ok.

Como estos son los pasos comunes en cada proyecto que trabajamos específicamente.

Luego from box from box import config box ok perfecto.

Entonces de Pathlib import path ok.

Y luego de teclear.

Así que voy a importar algunas de las bibliotecas y hablaremos de ello.

Por qué lo importamos específicamente.

De acuerdo.

Importa cualquiera.

Ahora aquí tenemos todas estas bibliotecas.

Ahora lo que voy a hacer es que probablemente voy a seguir adelante y definir sólo una funcionalidad que realmente

voy a utilizar, bien.

que será común a todo el proyecto.

Esto no es más que leer YAML.

De acuerdo.

Así que aquí podrás ver que tengo esto.

Estoy usando esta anotación ensure y básicamente estoy leyendo un archivo YAML.

Cualquiera que sea la ruta que he dado en este YAML, porque tengo un montón de archivos YAML, ¿verdad?

Así que aquí podrás ver que tengo params a YAML.

Tengo, tengo uh esquema YAML.

Bueno, también esquema YAML no es necesario por aquí, pero al menos YAML está ahí.

Y también habrá algo llamado como config YAML.

Bien.

Así que todos estos archivos YAML cuando estoy leyendo específicamente, usted sabe que va a volver en forma de cuadro de configuración.

Ahora, ¿cuál es la importancia de este cuadro de configuración y garantizar la anotación para que yo probablemente seguir adelante

y abrir un archivo dentro de mi investigación punto ipynb.

Muy bien, así que sólo voy a mostrar la funcionalidad de esta anotación garantizar y cuadro de configuración y por qué es importante.

Bueno, en primer lugar voy a seguir adelante y seleccionar mi núcleo.

Veamos si mi kernel se está ejecutando o no.

Así que esto se está ejecutando perfectamente.

Lo que voy a hacer es mostrarte la importancia de usar ese cuadro de configuración.

Y entonces sólo tú serás capaz de entenderlo bien.

Lo primero que haré será crear un diccionario de información.

De acuerdo.

Digamos que cuando creamos nuestro diccionario, ¿qué necesitamos?

Básicamente necesitamos pares clave-valor.

Bien.

Así que digamos que esta es la clave uno o digamos que voy a decir nombre de colon Krish.

Bien.

Y mi segunda clave puede ser el apellido Colon Nayak.

De acuerdo.

Así que este es básicamente mi nombre.

Ahora cada vez que sigo adelante y escribo dict subrayado info de nombre.

De acuerdo.

Aquí podrás ver que soy capaz de obtener el valor.

Pero si intento recuperar esta información en particular escribiendo así dict guión bajo info punto nombre, entonces

podrás ver que no soy capaz de leer este valor de nombre en particular.

Ahora la mayor parte de mi archivo YAML estará en esta forma particular pares clave-valor.

Y siempre es genial que en lugar de escribir la clave de esta manera en particular, vamos a tratar de escribir

esto de esta manera y probablemente deberíamos obtener la salida.

Bueno, así que para esto, con el fin de hacer esto como esto también debe ser una manera de probablemente

leerlo, ya sabes, así que lo que vamos a hacer que probablemente la importación de la caja de importación config.

De acuerdo.

Ahora ve esto bien.

Si sigo adelante y copio este diccionario de acuerdo en la información de subrayado lo pegaré aquí.

Y aquí voy a seguir adelante y escribir mi cuadro de configuración.

Así que si sigo adelante y ahora ejecutar este dict guión bajo info punto nombre que veo.

Probablemente siga adelante y muestre este flechazo.

Bueno, así que esto es lo que estamos haciendo específicamente porque todo nuestro archivo YAML tratará de mantener, eh, mantenerlo

en forma de pares clave-valor.

Bien.

Así que esa es la razón por la que vamos a utilizar específicamente.

De acuerdo.

Ahora hablaré también de asegurar la anotación.

Así que vamos a seguir adelante y crear mi función.

Así que digamos que voy a seguir adelante y escribir mi función es la suma bien.

Y aquí voy a dar dos valores como digamos x es igual a entero.

Y y también debe ser un entero bien.

Uh o uh, digamos que en vez de suma diré multiplicación.

Multiplicación.

De acuerdo.

Ahora aquí, una vez que seguir adelante y probablemente ver esto bien.

Así que aquí probablemente vamos a seguir adelante y devolver x multiplicado por y.

De acuerdo.

Así que esto es lo que es mi funcionalidad de multiplicación.

Así que aquí lo que estoy diciendo que mis parámetros es básicamente un formato int.

Y estoy recibiendo el valor en formato int bien.

Así que vamos a seguir adelante y ejecutar esto.

Ahora lo que voy a hacer yo sólo seguir adelante y abrir uh, llame a mi multiplicación y dar a mis valores,

digamos dos coma tres, y voy a ejecutarlo.

Recibo la respuesta seis.

Esto está muy bien.

Ahora, ¿qué pasa si probablemente llamo a esto?

Y en lugar de dar dos y tres, voy a tratar de dar en la cadena entonces.

Aquí podrás ver que este tres se convierte básicamente en dos.

¿Qué ha ocurrido exactamente?

Así es como esta es la operación que está teniendo lugar dentro de mi código de multiplicación.

De acuerdo.

Normalmente, esto no debería ocurrir, ¿verdad?

Probablemente debería obtener un error si lo estoy dando como una cadena, porque aquí he dicho que hey,

mi por qué debe ser un valor entero, pero esto no está sucediendo.

Así que para esto, lo que realmente necesitamos hacer es que vamos a utilizar algo llamado como asegurar anotación.

Así que para asegurar voy a importar la anotación ensure.

Y luego voy a seguir adelante y escribir asegurar anotación.

Uh definición.

Digamos que voy a seguir adelante y escribir la misma definición aquí de acuerdo.

La misma definición.

Y me limitaré a escribir devolver x coma x multiplicado por y.

Así que aquí ahora si sigo adelante y llamar a la misma cosa ahora y si trato de ejecutarlo esta vez no se ejecutará.

Me dará un error.

Bien.

Así que está diciendo que hey su argumento y de tipo clase str para ser una función.

Así que este es el valor que usted debe estar recibiendo ¿verdad?

Así que esa es la razón por la que tienes que implementar o utilizar este decorador llamado como asegurar anotación para que cualquiera

que sea la entrada que está básicamente dando debe ser del mismo tipo de datos.

De lo contrario, se producirá un error.

¿Verdad?

Porque este tipo de funciones las vamos a utilizar a medida que avancemos.

Así que es necesario que utilices todas estas cosas.

Bien.

Así que esa es la razón aquí con respecto a leer YAML, si estoy dando una ruta a YAML en forma de ruta,

entonces sólo se debe ejecutar.

Si sólo le doy una ruta normal, no se ejecutará.

Así que esta es una de mis funcionalidades con respecto a la lectura de YAML.

Ahora la otra funcionalidad si estamos leyendo YAML.

Así que una función más común que vamos a crear es algo llamado como crear directorios.

De acuerdo.

Así que con el fin de crear directorios de nuevo estoy escribiendo asegurar anotación crear directorios.

Esta es mi ruta a los directorios, la lista de ruta.

Y aquí sólo estoy diciendo que a partir de ruta en ruta guión bajo dos directorios guión bajo OS punto hacer directorios.

Tomo el camino y digo que si existe déjalo así.

Si no, adelante, probablemente lo cree.

Esto básicamente creará el directorio.

Y estoy escribiendo.

Si verbose es true probablemente tenga que registrar bien esta información en particular.

Y básicamente lo estamos registrando bien.

Y también podemos encargarnos de la parte de registro.

Ahora una vez hecho esto para crear los directorios el uh crear directorios y leer directorio YAML.

Así que estas dos funcionalidades que voy a utilizar específicamente porque en nuestro proyecto leer YAML y en la creación de directorios

será una de las funcionalidades muy importantes.

Así que espero que les guste este vídeo en particular.

Hasta aquí.

Ahora hemos implementado o puesto en marcha nuestras funcionalidades comunes.

Ahora es el momento de que a partir del próximo video vamos a tratar de ver que modelo vamos a utilizar de la cara de

abrazo.

Junto con eso, qué conjunto de datos vamos a utilizar específicamente.

Vale, así que sí, esto era todo por mi parte.

Nos vemos en el próximo vídeo.

Gracias, señor.
"""

# %%
finetunning_Hugging_face_models_Google_Colab = """
Hola, chicos.

Así que vamos a continuar el debate con respecto a nuestro proyecto integral.

Uh, ya hemos creado las funcionalidades comunes.

Ya tenemos lista nuestra plantilla punto pi.

Eso significa básicamente toda la estructura de mi proyecto.

Junto con eso, también hemos implementado la funcionalidad de registro aquí.

Dentro de esto has visto que hemos implementado la funcionalidad de registro.

Junto con que las utilidades comunes uh funcionalidades también implementado donde implementamos leer YAML,

crear directorios, todo este tipo de funciones bien.

Ahora el siguiente paso es que vamos a empezar a trabajar en nuestro, uh, ya sabes, todo el como yo realmente necesita para mostrar, en primer lugar, con

la ayuda de Jupyter Notebook, que cómo usted probablemente puede seguir adelante

y trabajar con los modelos de la cara abrazos en sí.

Y así, en primer lugar, lo que voy a hacer es que porque vamos a afinar nuestro modelo con nuestro conjunto de datos,

¿verdad?

Así que, obviamente, todo ese proceso de ajuste fino, voy a tratar de mostrar en el cuaderno Jupyter.

Y entonces probablemente podamos seguir desarrollando el proyecto de principio a fin.

Así que lo que voy a hacer es que sólo tiene que ir a su Google Colab.

Vale, esto es básicamente tu Google Colab.

Y dentro de este particular Google Colab, usted será capaz de ver que tengo este archivo en particular

llamado como texto resumido punto Ipynb.

De todos modos, voy a poner este archivo en particular dentro de mi carpeta de investigación dentro del proyecto.

De acuerdo.

Ahora, en primer lugar, lo que hay que hacer es que usted necesita para seguir adelante y cambiar su tiempo de ejecución.

De acuerdo.

Ahora dentro de esto he seleccionado L para GPU porque tengo una cuenta de Google Colab de pago.

De acuerdo, pero si no tienes una cuenta de pago de Google Colab, entonces puedes seguir adelante y seleccionar T para GPU

también.

Bien, aquí voy a usar L para GPU.

Voy a seguir adelante y guardar esto.

De acuerdo.

Ahora vamos a conectar esto.

Ahora, una vez que nos conectamos específicamente paso a paso tratará de entender cómo funciona todo esto pasos.

De acuerdo.

Ahora este es mi, uh, mi, mi cuenta de Google Colab está básicamente conectado.

Ahora, mira, lo que es mi plan principal es que realmente necesito usar este modelo en particular que es Google Pegasus.

Modelo CNN underscore Daily Mail para mi tarea de resumen de textos.

Y para ello voy a utilizar unos datos que se denominan conjunto de datos.

Uh, como aquí están sus datos de Samsung va a utilizar estos datos específicos.

Hablaremos más sobre esto como estos datos tienen tres campos importantes.

Uno es el diálogo el texto del diálogo.

Luego está el resumen, que no es más que un resumen humano escrito del diálogo.

Y entonces usted tiene este ID único de un ejemplo.

De acuerdo.

Aquí tienes tu conjunto de datos de entrenamiento, tu validación, tu conjunto de datos válidos y tu conjunto de datos de

prueba.

De acuerdo.

Así que todo este conjunto de datos en particular está disponible aquí.

Ahora lo que voy a hacer es que, uh, voy a volver a mi Summarizer texto.

Y te mostraré paso a paso cómo puedes probablemente seguir adelante y cargar este modelo en particular y afinar

el conjunto de datos.

Y por aquí, cada vez que hablo de este modelo diario Google Pegasus CNN.

Debe entender que esto se basa en un modelo de secuencia a secuencia.

Bien, ahora para el modelo secuencia a secuencia definitivamente requieres un tokenizador un tokenizador específico.

Así que aquí si probablemente seguir adelante y ver y utilizar este modelo.

Y si usted ve en el transformador en el Summarizer, usted será capaz de ver que auto tokenizer de modelo pre-entrenado.

Así que este es tu modelo pre-entrenado.

También utilizaremos el modelo automático de secuencia a secuencia.

Ahora mismo este modelo automático para secuencia a secuencia no es nada, pero es una biblioteca que básicamente está entrenando

un modelo de secuencia a secuencia.

Bien.

Así que este Google Pegasus, CNN, Daily Mail es ese tipo de modelo.

Además, puede seguir adelante y leer la documentación más acerca de este modelo en particular, lo

que hace este modelo y cómo funciona básicamente.

De acuerdo.

Así que eh, espero que seas capaz de entender hasta aquí.

Ahora sigamos adelante y ejecutémoslo paso a paso.

Y luego probablemente también te explique el código.

Uh, pero cualesquiera que sean los métodos genéricos que probablemente estamos siguiendo aquí lo mismo.

También puedes hacerlo con el otro modelo.

Así que vamos a proceder y discutir más sobre ello.

Perfecto.

El primer código que vamos a ejecutar es Nvidia SMI.

Esto sirve básicamente para comprobar qué modelos estamos utilizando específicamente.

Y en este momento usted sabe que hemos asignado uh, que lo siento, que GPU estamos utilizando.

Y ahora mismo tenemos básicamente asignado Nvidia L4.

Así que si has asignado otras GPUs por aquí basadas en el tiempo de ejecución como T para GPU, entonces eso será visible

por aquí.

De acuerdo.

A continuación, vamos a utilizar este transformador Sentencepiece conjunto de datos ROC puntuación.

Esta puntuación ROC será mi métrica de rendimiento a calcular para este modelo en particular.

Pero estas son sólo algunas importaciones que estamos haciendo de transformadores a conjunto de datos a la puntuación ROC y todo.

Así que por favor siga adelante e instale esta biblioteca en particular.

Porque vamos a utilizar este uh para cargar probablemente nuestro modelo y todo.

De acuerdo.

Así que aquí se puede ver que mi instalación se ha completado porque ya he ejecutado y acaba de reiniciar el

kernel en pocas palabras.

De acuerdo.

A continuación, junto con esto, lo que vamos a hacer es que también vamos a actualizar nuestro acelerar.

Ahora deberías entenderlo todo.

Por qué se utiliza específicamente la aceleración.

Sabes que lo hará.

Te dará una buena idea para entender básicamente todo el proceso.

De acuerdo.

Ahora hay algunas de las bibliotecas comunes que utilizamos específicamente cuando estamos trabajando con la cara

de abrazo.

De acuerdo.

Y lo proporciona la propia cara abrazadora.

Bien.

Así que uno es como acelerar.

Uno es como transformar, acelerar.

Usted sabe, y utilizamos específicamente esto para asegurarse de que asignamos cada vez que estamos entrenando específicamente sucede.

Asigna todos los trabajos, eh, todos los trabajos de una mejor manera a las GPUs.

Bien.

Esa es la razón por la que utilizamos específicamente este acelerador.

De acuerdo.

Así que lo que voy a hacer, es seguir adelante y también escribir algunos, uh, comentarios por aquí para que usted

sea capaz de entender.

Así que vamos a seguir adelante y escribir este propósito de la aceleración.

De acuerdo.

Y esto es importante porque en la entrevista pueden preguntarte lo siguiente.

De acuerdo.

Así que uno es la facilidad de entrenamiento multidispositivo de acuerdo.

Y la segunda es de precisión mixta.

Y el tercero es algo llamado como cero uh, reducir uh redundancia u optimizador.

De acuerdo.

¿Para qué sirve el acelerador?

Es la facilidad del entrenamiento multidispositivo.

Tanto si utiliza varias GPUs como TPUs, accelerate facilita el escalado de su modelo en distintos dispositivos con cambios

mínimos en el código.

De acuerdo.

Entonces tienes esta precisión mezclada.

Permite entrenar modelos con precisión mixta, lo que puede acelerar el entrenamiento y reducir el

uso de memoria.

Además, el optimizador de redundancia cero ayuda a gestionar modelos de gran tamaño dividiéndolos eficazmente

en varios dispositivos.

Y todos estos pasos están básicamente ahí.

De acuerdo.

Entonces, eh, lo que básicamente vamos a hacer es que vamos a seguir adelante e instalar todo

esto acelerador de transformador y todo.

De acuerdo.

Uh, así que en primer lugar, lo que tenemos que hacer es que tenemos que actualizar esto.

Luego tenemos que desinstalar, que es el anterior, y luego estamos de nuevo la instalación de Transformer Accelerate.

Así que permítanme ir rápidamente por delante y ejecutar esto.

Y creo que esta instalación ya está bien.

Así que voy a seguir adelante y reiniciar la sesión.

Así que probablemente le pedirá que reinicie la sesión después de que todo esto se ejecute.

De acuerdo.

Así que ahora um, vamos a ejecutarlo de nuevo ok.

Lo hará, puede que te pida que reinicies la sesión, pero no te preocupes.

Uh, así que aquí tienes todos estos pasos.

De acuerdo.

Una vez hecho esto, pasamos al siguiente paso.

Ahora en este siguiente paso, uh, usted será capaz de ver que tenemos estamos importando transformadores.

Estamos utilizando tuberías.

De acuerdo.

Hablaremos de este conducto en las etapas posteriores.

Um, uh, veamos, uh, también estamos importando dos librerías importantes llamadas como load underscore data set

y load from disk.

De acuerdo.

Ahora, el conjunto de datos que voy a utilizar específicamente, ya sabes, te dije que vamos a utilizar

el conjunto de datos de Samsung.

Ya sabes, lo que he hecho es que con el fin de sólo y si usted sabe, si usted ve este conjunto de datos, usted tiene tres

principales cosas importantes como el diálogo, el texto de los diálogos, resumen, resumen escrito humano del diálogo,

a continuación, ID único de ese ejemplo.

Y luego tienes este conjunto de datos válidos de validación de entrenamiento y conjunto de datos de prueba ok.

Ahora con respecto a este conjunto de datos en particular usted será capaz de ver tres ver toda esta información

en particular.

Ahora lo que he hecho es que en lugar de descargar el conjunto de datos en el y guardarlo en algún lugar.

Lo que he hecho es que he subido esto en mi GitHub.

De acuerdo.

Y aquí usted será capaz de ver una vista enlace crudo bien.

Así que voy a descargar este zip directamente, llamando desde mi código y descargarlo y descomprimir y descomprimir ese conjunto de datos

en particular.

De acuerdo.

Así que esa es la razón por la que estamos utilizando este conjunto de datos de subrayado de carga y carga de subrayado de carga desde el disco.

De acuerdo.

Entonces uh también estoy importando pandas, como he dicho que a partir de Transformers, vamos a utilizar dos cosas importantes.

Uno es el modelo automático de secuencia a secuencia lm y el tokenizador automático.

Auto tokenizer es una biblioteca que se utilizará específicamente, ya sabes, para convertir tu texto en tokens.

Así que para cada modelo que está disponible en hugging face, sabes que habrá un auto tokenizer, uh, que

será compatible con ese modelo, que y su responsabilidad es básicamente convertir tu, uh,

tu código en texto.

De acuerdo.

Lo siento.

Tu, tu texto en, uh, tokens.

De acuerdo.

Esa es la razón por la que utilizamos específicamente el tokenizador automático.

Y de forma similar tienes este modelo auto auto para LM de secuencia a secuencia.

Esto se utiliza básicamente sólo para cargar este modelo en particular, cualquiera que sea el modelo que está utilizando específicamente.

Así que aquí también podrás ver que, hey, uh, tengo todas estas cosas y también puedo utilizar directamente este modelo

en particular.

De acuerdo.

Y digamos que si quiero también quiero seguir adelante y crear una tubería, voy a ser capaz

de crear por aquí.

Así que si vas por aquí y hacia abajo, a la derecha.

Y si sólo intenta utilizar este modelo, también puede ejecutar directamente esto.

Y probablemente puedas ejecutar el código con sólo leer la documentación del modelo.

De acuerdo.

Pero nuestro objetivo principal no es sólo utilizar esto como ver hay un ejemplo aquí a la derecha.

Lo que estamos haciendo es cargar el modelo pre-entrenado.

Y entonces si probablemente considere esto copiemos esto ok.

Copiaré esto y lo pegaré aquí.

Pero antes de esto vamos a ejecutar esta bien.

Entonces serás capaz de entender lo que realmente estoy tratando de decir bien.

Así que en primer lugar vamos a tratar de ejecutar esto y vamos a uh importar este NLTK que requerimos específicamente

para tokenizer frase bien.

Ahora lo que voy a hacer es seguir adelante y ejecutar esto.

Ahora lo que aquí estamos haciendo es que estamos uh, estamos básicamente tomando el modelo que es Google Pegasus

XM.

Entonces probablemente estemos cargando el tokenizador.

Tokenizer.

Básicamente para convertir las palabras en palabras.

Este es el resumen de mi artículo.

Y luego aplicaremos este tokenizador a este resumen de artículo.

Y diré que, oye, la longitud máxima es 1024.

Y los tensores, sólo devolverá los tensores en este formato.

De acuerdo.

A continuación, con el fin de generar el resumidor para este texto en particular, sólo puedo seguir adelante y escribir generador

de puntos modelo de entrada con ID de entrada.

Así que las entradas de aquí cuando probablemente seguir adelante y ejecutar este tokenizer, esto probablemente obtener

generar un ID de entrada bien vamos a ver que.

Y entonces volveré.

Voy a convertir esto de nuevo de mis identificaciones a mi texto bien.

Y aquí estoy usando el ID de resumen y el token especial skip es igual a true.

Eliminará todos los tokens innecesarios que están presentes en el interior que usted conoce como token de espacio o un token

claro, algunos tokens especiales que se añadirán.

Así que vamos a seguir adelante y ejecutar esto.

Comprenderás cómo utilizar este modelo de una forma mucho más sencilla.

Aquí sólo estoy cargando un modelo.

Estoy tomando un texto y probablemente, uh uh, averiguando el resumen de este texto en particular.

De acuerdo.

Así que permítanme explicarlo de nuevo.

En primer lugar, cargamos el modelo.

Luego cargamos el tokenizador.

Este es mi artículo.

Estoy convirtiendo este artículo en uh tokens.

De acuerdo.

Y entonces voy a estar generando sobre la base de que las fichas particulares.

Y vuelvo a convertir eso en una frase.

De acuerdo.

Así que aquí puedes ver que el truncamiento estaba explícitamente activo.

Esto está ahí.

Y aquí está su uh, ver por aquí PG.

Empezó con esto esto esto.

Y toda la información está aquí.

Con ello se pretende reducir los cerca de 8.000 clientes que está previsto que se vean afectados por los

cortes.

Así que aquí puedes ver que viene un resumen.

El mayor proveedor de electricidad de California ha cortado el suministro a cientos de clientes.

Ya está.

De acuerdo.

Una manera muy fácil de probablemente hacer esto, pero mi objetivo principal no es sólo para recuperar los datos de la, eh, quiero decir,

sólo tiene que cargar el modelo y hacer la predicción.

Ese no es mi principal objetivo.

Mi objetivo principal es básicamente afinar, ¿no?

Así que ajuste fino con los datos personalizados.

Bien, esto es lo que vamos a hacer básicamente.

De acuerdo.

Ahora continuemos.

De acuerdo.

Así que porque esto es sólo para uno esto es sólo un o aquí sólo voy a seguir adelante y escribir funcionalidad básica

básica de modelo de cara de abrazo.

Al igual que aquí básicamente le muestra cómo usted puede probablemente cargar esto y cómo usted puede seguir adelante y ejecutar

este bien.

Ahora en el siguiente paso lo que voy a hacer.

Así que de nuevo voy a importar esto.

Este dispositivo es igual a Cuda.

Si antorcha punto Cuda está disponible o no.

Uh esto sólo va a mostrar si vamos a utilizar GPU o no.

Si estás usando GPU, simplemente mostrará Cuda.

De acuerdo.

Así que vamos a seguir adelante y mostrar esto.

De acuerdo.

Cuda básicamente se está exhibiendo.

Eso significa básicamente que estamos utilizando um nuestra GPU.

Ahora voy a seguir adelante y comenzar mi proceso de ajuste fino.

¿Ves esto?

Esto es muy importante.

Y esto le dará una idea de cómo usted probablemente puede hacer un ajuste fino para cualquier, cualquier, cualquier tipo de modelo con

cualquier tipo de conjunto de datos que tiene.

Así que en primer lugar voy a cargar mi modelo.

Así que la barra de Google Pegasus CNN subrayado diario.

Así que antes de esto no.

Así que aquí podrás ver algunos archivos están ahí.

No te preocupes, también hablaré de esos archivos.

Este es mi modelo.

Google slash Pegasus CNN Daily Mail.

Uh aquí estamos básicamente va a utilizar un tokenizer.

Así que esto es sólo para cargar un tokenizer, cargar un tokenizer.

Y su trabajo principal es básicamente convertir nuestro texto en tokens.

De acuerdo.

A continuación, estamos utilizando este modelo automático de secuencia a secuencia de modelo pre-entrenado para el dispositivo bien.

Así que básicamente estamos cargando el modelo.

Así que este código es sólo para cargar el modelo.

Y el tokenizador que se utiliza para este modelo en particular que es Pegasus CNN Daily Mail bien.

Ahora este modelo en particular tamaño un poco pequeño.

De acuerdo.

Así que no tienes que preocuparte porque si hay un modelo enorme por ahí, entonces de nuevo necesitas

tener mucha Ram y disco, vale.

Ahora, el tipo de conjuntos de datos que estoy utilizando, ya te dije que he cargado un conjunto de datos

aquí.

Hablaremos más sobre ese conjunto de datos en particular y cómo es.

De acuerdo.

Así que volveré aquí.

Así que lo que estoy haciendo es que estoy descargando y descomprimiendo los datos.

Así que he dado el enlace del conjunto de datos y estoy usando wget.

Y estoy descomprimiendo todo este resumen de datos punto zip.

De acuerdo.

Así que vamos a ejecutar esto.

Así que aquí están mis datos completos.

Datos completos.

Así que esto básicamente se está descomprimiendo bien.

Y se guardará aquí bien.

Así que me pregunta si debemos reemplazar esto o no.

Así que déjame hacer una cosa.

Permítanme seguir adelante y escribir sí para usted.

Si lo estás descargando por primera vez, me limitaré a escribir un.

Bien, ahora por primera vez, si estás ejecutando, podrás ver que todo tu conjunto

de datos se creará aquí.

Bien.

Así que este es mi conjunto de datos, el conjunto de datos de Samsung.

Aquí tienes tus datos de prueba.

Aquí tienes los datos de tu tren.

Y aquí tienes tus datos válidos de acuerdo.

Así que todos estos conjuntos de datos están básicamente disponibles en este formato particular en nuestra cara de abrazo.

Ya sabes, en esta particular cara de abrazo.

Y usted puede utilizar esos datos específicos en sí está bien.

Directamente.

Uh, si usted no tiene esto entonces probablemente tenemos que construir de esta manera.

De acuerdo.

Junto con eso también tendrá su prueba de Samsung punto CSV.

Así que si sigo adelante y hago doble clic en esto, así es como se ve mi conjunto de datos.

Bien aquí tienes tu ID, tienes tu diálogo y tienes tu resumen.

Así que este es tu diálogo.

Este es su resumen basado en su... diálogo.

Usted tiene un resumen específico, entonces toda esta información es básicamente allí.

De acuerdo.

Este es el conjunto de datos que vamos a utilizar.

Del mismo modo tienes este tren punto CSV.

Aquí tienes esta validación punto csv bien.

Todos los archivos están básicamente ahí.

Perfecto.

Ahora lo que vamos a hacer es que cualquier carpeta que tenemos aquí.

Bien.

Y si usted ve dentro de estos datos de prueba, este conjunto de datos en particular está en el formato de flecha bien.

Flecha.

Así flecha también está ahí que será como numpy sí mismo, pero un poco diferente de numpy.

De acuerdo.

Ahora lo que haremos.

Cargaremos esto dentro de la carpeta Samsung data set.

Y hay una función en huggingface que se llama como carga desde disco.

Bien.

Así que lo que hace es que cada vez que encuentra ese tipo de archivos como flecha y JSON de un formato específico, entonces

si usted acaba de utilizar esta función, lo hará, se cargará los datos y se convertirá en un diccionario

de datos.

De acuerdo.

En el diccionario de datos, usted será capaz de ver que va a tener como dentro de esa carpeta que tiene que tres carpetas

principales, a la derecha.

Uno es el tren de pruebas y la validación.

Así que teniendo esto en cuenta aquí también será capaz de obtener la prueba de tren y validación.

Así que aquí vamos a ejecutar esto y luego vamos a tratar de entender esto bien.

Así que aquí tienes este conjunto de datos.

Aquí tienes características ID diálogo resumen.

Y el número de filas es nada más que 14732 ok.

Del mismo modo para la prueba que tiene esta característica en particular tengo número de filas como 819.

Y el conjunto de datos de validación tiene alrededor de 880.

De acuerdo.

Así que esto es lo que hemos cargado el conjunto de datos.

Está en formato de diccionario de conjuntos de datos.

Ahora que viene al siguiente paso aquí usted será capaz de ver que lo que aquí es un conjunto de códigos que estamos

tratando de entender.

Por ejemplo, cuál es la longitud de los datos de entrenamiento, los datos de prueba y los datos de validación.

Así que aquí lo que he hecho, he tomado este conjunto de datos en particular y estoy escribiendo para dividir en conjunto

de datos guión bajo Samsung bien.

Así que si probablemente seguir adelante y ver con respecto al conjunto de datos subraya que entrenar prueba y validación de datos,

¿verdad?

Así que para cada longitud básicamente vamos a seguir adelante y mostrarlo en la lista.

Bien.

Así que se está mostrando así.

Entonces usted tiene esta características cualesquiera que sean las características, cualesquiera que sean los nombres de columna está ahí en el tren.

Básicamente vamos a mostrarlo.

Y un ejemplo a la derecha estoy imprimiendo Samsung prueba, un diálogo y un resumen.

Ver diálogo es una característica, ID es la otra característica, y resumen es la otra característica.

Bien, sólo estoy mostrando el diálogo y el resumen.

Así que una vez que ejecute este código aquí, usted será capaz de ver que esta es mi longitud de división bien.

Esto es para mi prueba de tren y validación.

Estas son mis características.

Y aquí tengo mi diálogo donde estoy diciendo que Eric, uh, toda esta información está ahí.

De acuerdo.

Y este es básicamente mi resumen.

De acuerdo.

Del mismo modo, si sigo adelante y veo para mis próximos datos de prueba, si sigo adelante y probablemente mostrar el diálogo de los próximos

datos de prueba.

Debería poder verlo.

Así que este es mi diálogo para todo mi conjunto de datos.

Y este es mi resumen.

De acuerdo.

Así que estos datos que sólo estoy tratando de mostrar cómo es que los datos se parece.

De acuerdo.

Perfecto.

Ahora tenemos que preparar los datos para el entrenamiento del modelo secuencia a secuencia.

A ver si tengo un dato como este diálogo.

Hola, ¿cómo estás?

El resumen dice que el hablante pregunta cómo está la otra persona.

Por lo general, este tipo de datos debe convertirse en tres campos principales.

Así que aquí tienes ID de entrada.

El ID de entrada no es más que el ID de los tokens para el diálogo.

Así que cualquiera que sea el tokenizador automático que estamos utilizando específicamente que convertirá sus entradas sus sus palabras en algunos

tokens.

De acuerdo.

Y eso es realmente necesario para cualquier, cualquier modelo que se entrene con el modelo secuencia a secuencia.

De acuerdo.

Entonces tienes esta máscara de atención.

La máscara de atención es sólo para aplicar algunos caracteres especiales dentro de esta, uh, palabra A en forma de tokens, ok, que serán

útiles para el modelo secuencia a secuencia, uh, para implementar o para hacer la predicción o para afinar

el modelo.

De acuerdo.

A continuación, el tercer parámetro que tenemos es algo llamado como etiquetas.

La etiqueta no es nada, pero es un ID de token para el objetivo de resumen.

Digamos que este es mi objetivo resumido.

Así que para esto uh vamos a aplicar un tokenizer y vamos a convertir este uh palabras en este token particular.

Así que lo mismo tenemos que hacer para este conjunto de datos en particular antes de pasar mis datos al modelo de secuencia

a secuencia.

Así que aquí lo que estamos haciendo es que aquí estamos creando un ejemplo bien.

Así que convierta el ejemplo en características.

Así que en primer lugar para convertir en la codificación de entrada voy a utilizar el tokenizer Voy a tomar ejemplo

lote de diálogo.

El diálogo no es más que mi mi mi mi campo de entrada vale.

Y entonces estoy diciendo aquí el uso de la longitud máxima de 1024 y truncamiento es igual a verdadero bien.

A continuación, con tokenizer como tokenizer objetivo también vamos a convertir mi resumen uh en tokens.

De acuerdo.

Pero tenemos que utilizar esto probablemente como un tokenizer objetivo, porque lo que pasa es que tokenizer si se está utilizando

para una entrada.

Del mismo modo, lo que podemos hacer es que para el objetivo, cómo se debe convertir, en realidad podemos utilizar

esta función en particular bien.

Así que aquí también estamos utilizando el resumen del lote de ejemplo.

Estamos utilizando la longitud máxima es igual a 128.

Y finalmente vamos a tener el truncamiento es igual a verdadero bien.

Y entonces aquí estás devolviendo tus ids de entrada tu máscara de atención y tus etiquetas ok.

Que no es otra cosa que sus codificaciones objetivo de ID de entrada.

Así que vamos a seguir adelante y ejecutar esto.

Ahora bien, esta función en particular podemos aplicarla a todo mi conjunto de datos, eh, de Samsung que está en forma de diccionario.

Bien.

Este conjunto de datos diccionario derecho.

Así que una vez que aplique esto convertiré el ejemplo en características.

Y lote es igual a verdadero.

Así que vamos a seguir adelante y ejecutar esto.

De acuerdo.

Vamos a ejecutar esto.

Así que aquí he ejecutado.

Y luego uh voy a seguir adelante y ejecutar mi conjunto de datos underscore Samsung underscore tren.

Ahora mira esto.

De acuerdo.

Una vez que ejecute esto bien podrás verlo.

Ahora en mis características simplemente no tengo tres campos.

Tengo más campos adicionales como máscara de atención de ID de retorno y etiquetas.

Así que también está incluido en mi conjunto de datos de entrenamiento.

Y si también sigues adelante y ves en los datos de prueba, tu conjunto de datos puede haberse actualizado con estas tres características.

Es decir, ID de entrada, máscara de atención y etiquetas.

Y esto es muy importante para la formación.

Bien, ahora vamos al siguiente paso.

Lo que voy a hacer es que, uh, mira, mientras estamos entrenando con el modelo uh secuencia a secuencia, necesitamos

usar este recopilador de datos para secuencia a secuencia.

De acuerdo.

Lo que hace esto es que, uh, esto se asegura de que cualquier dato que tengamos específicamente, trata de convertirlo en lote

para que pueda ser proporcionado al modelo para el propósito de entrenamiento.

Así que para esto, básicamente, seguir adelante y inicializar colector de datos para la secuencia a la secuencia de acuerdo.

Y aquí podrás ver esto bien.

déjame hacer una cosa.

Permítanme, um, permítanme seguir adelante y probablemente, uh, escribir algunas definiciones para que usted sea capaz de, uh,

ver esto.

De acuerdo.

Así que voy a copiar esto aquí y déjame crear un texto y déjame escribirlo aquí.

De acuerdo.

Así pues, el recopilador de datos para secuencia a secuencia es un recopilador de datos especial diseñado para el modelo secuencia

a secuencia que ayuda a preparar lotes de datos de entrenamiento para el entrenamiento.

De acuerdo.

Así que vamos a usar esto específicamente aquí.

Sólo tenemos que proporcionar el tokenizer y el modelo correcto.

Cualquiera que sea el nombre del modelo que estamos definiendo básicamente bien.

Y eh aquí si ves que ya he definido mi modelo como Modelo Pegaso.

Bien.

Supongo que he definido de esa manera.

Um hmm.

Bien, tu modelo Pegaso está por aquí.

Perfecto.

Volvamos a nuestro código.

Así que hemos ejecutado esto.

Ya lo hemos visto.

De acuerdo.

Ahora, lo que tenemos que hacer para afinar nuestros datos, ver nuestros datos.

En primer lugar, lo hemos preparado donde realmente necesitamos que añadas tres cosas importantes.

Uno es el ID de entrada, la atención, la máscara y las etiquetas.

El siguiente paso consiste en utilizar argumentos de formación con el formador.

Así que desde transformador de importación de formación argumentos entrenador uh, aquí usted será capaz de ver que mi directorio

de salida no es más que uh Pegasus Samsung Estoy usando un directorio de salida.

Así que digo que el número de épocas de entrenamiento es uno.

Los pasos de calentamiento irán a cinco.

Mira, la razón por la que estoy haciendo el número de épocas es uno porque eh, es un conjunto de datos muy grande bien.

Y sólo quiero hacer una y mostrártela más tarde.

Puedes intentarlo con tu GPU tantas veces como quieras.

De acuerdo.

Entonces, por dispositivo, el tamaño del lote de guiones bajos es igual a uno.

Entonces, el tamaño del lote de evaluación por dispositivo es igual a uno.

Entonces tenemos este decaimiento de peso pasos de registro es igual a diez.

Pasos de la estrategia de evaluación

Toda esta información está básicamente ahí bien.

Ahora aquí usted va a seguir adelante y ejecutar esta bien.

Y, finalmente, vamos a seguir adelante y ejecutar mi entrenador.

Así que entrenador es igual a modelo Pegasus argumentos entrenador argumentos token es igual a tokenizer.

Recopilador de datos.

Básicamente estamos usando.

Y en lugar de dar todo mi conjunto de datos de tren, estoy dando conjunto de datos de prueba porque mi conjunto de datos de prueba

es más pequeño que el tren.

Sólo para asegurarse de que, uh, nuestra formación se produce rápidamente.

De acuerdo.

Y luego el conjunto de datos de evaluación, vamos a establecerlo en evaluación.

Así que si recuerdas el tamaño es en algún lugar alrededor de 870 y 870.

Esto es lo que hemos creado.

Nuestro entrenador nuestro entrenador afinado.

Y luego vamos a escribir entrenador punto entrenador ok.

Así que finalmente uh entrenador. tren.

Y estamos usando esto específicamente.

Así que ahora mi formación ha comenzado en realidad y que va a tomar una cierta cantidad de tiempo una vez que toda esta formación

ocurre, lo que vamos a hacer es que, en primer lugar, eh, hacer algunas cosas múltiples como vamos a guardar este

modelo también que también parte en realidad voy a mostrar a usted.

Bien, déjame minimizar esto.

Perfecto.

Ahora vamos a ver con respecto a la evaluación.

Ahora con respecto a la evaluación, en primer lugar vamos a crear una función que se llama como definición

generar guión bajo lote guión bajo tamaño guión bajo trozo.

Esto sólo va a dividir los datos en lotes más pequeños para que podamos procesar simultáneamente bien.

Así que digamos que si estoy dando una lista con los seis caracteres y si digo que mi tamaño de lote es de tres,

entonces esto se convertirá en 123 y 456.

Así está bien.

Y entonces uh vamos a seguir adelante y probablemente uh, así que aquí se que es lo que está haciendo básicamente.

Bien.

Así que cualquier uh, lista de elementos que estamos dando básicamente aquí, sólo se convertirá en lotes.

De acuerdo.

Entonces tenemos esto calcular métricas en los datos de prueba bien.

Así que aquí vamos a estar proporcionando conjunto de datos métrica modelo tokenizer tamaño del lote dispositivo columna de texto

como nuestro artículo y nuestro resumen de la columna como destacados Muy bien, así que este es el nombre que voy a especificar.

Ahora cualquier artículo que básicamente dar digamos que todo mi texto.

En primer lugar, vamos a dividirlo en lotes.

Del mismo modo con respecto a nuestro objetivo digamos que en mis datos de prueba tendré tanto entrada como salida.

Bien.

Así que este objetivo también lo convertiré en un tamaño de lote.

A continuación, para el lote de subrayado de artículo y el lote de subrayado de destino.

En Tqdm vamos a comprimir esta cosa en particular.

Y uno por uno vamos a pasar ese derecho.

Por qué estamos pasando básicamente porque tenemos que aplicar el tokenizer.

A continuación, vamos a seguir adelante y generar el resumen de que el integrador en particular bien.

Lo siento.

Generará para esa entrada en particular generará el Summarizer.

De acuerdo.

Entonces uh, decodificaremos ese Summarizer en particular usando cualquier versión resumida que tengamos.

Lo decodificaremos con la ayuda de tokenizer.

Y luego los resúmenes decodificados que tengo voy a reemplazar esto, eh, y voy a eliminar los valores

vacíos con esto a algunos valores vacíos en sí.

¿Verdad?

Y luego seguiré adelante y añadiré ese lote en particular.

De acuerdo.

Ahora esta función métrica que hemos utilizado específicamente.

Bien.

Proporcionaremos algunas métricas allí.

Y hay un par de métricas que utilizamos básicamente en el caso de resumen de texto como la puntuación

bruta de desplazamiento azul, diferentes puntuaciones diferentes están ahí y vamos a hablar más sobre ello.

Así que una vez que seguimos adelante y escribimos punto métrico, añadir predicciones de lote de referencia de resumen decodificado es igual

al lote de destino.

Así que cualquiera que sean los resúmenes decodificados que tengamos y cualquiera que sea nuestro lote objetivo, ambos se compararán bien.

Por último, calculamos esa métrica concreta y obtenemos la puntuación.

Eso es lo que hace básicamente.

De acuerdo.

Así que aquí se puede ver que mi modelo se ha entrenado con éxito para una época.

Y esto es suficiente.

Como que tengo una cosa aquí.

Podrás ver la pérdida de entrenamiento y todas las épocas.

Cuánto y muestra de entrenamiento por segundo tiempo de ejecución del entrenamiento.

Toda la información está básicamente ahí.

De acuerdo.

Ahora vamos a seguir adelante y ejecutar esto para las dos cosas.

Una es para la evaluación.

A continuación, vamos a seguir adelante e instalar esta biblioteca, que se llama como pip install evaluar.

De acuerdo.

Esto será necesario.

Y ahora aquí usted será capaz de ver que estoy importando evaluar y voy a decir evaluar punto de carga ROG bien.

Esta es una de las métricas ROG que utilizamos específicamente.

Esto es como un prerrequisito que realmente necesitas tener.

Si realmente necesito comparar dos textos diferentes o uno básicamente haciendo una predicción a partir de un modelo

y otro de un formato humano, vale.

Para eso tenemos diferentes parámetros como ROG, ROG, one Rock, two, ROG, L, ROG, L sum, e incluso hay algo

llamado como bleu score, correcto.

Y sobre cuya base se han redactado básicamente los trabajos de investigación.

Así que utilizaré esta métrica ROG en particular.

Entonces tengo este ROG nombres de ROG uno Rock, dos ROG, L, ROG algunos.

Voy a seguir adelante y ejecutar esto.

Vamos a ROG, eh, vamos a tomar probablemente esta métrica en particular.

Ahora, si sigo adelante y veo mi métrica ROG subrayado y si ejecuto esto, usted será capaz de ver aquí lo que son

la información con respecto a esto.

Bien.

Así que aquí se puede ver uh, si las predicciones es como hola allí General Kenobi y referencias está ahí.

Hola, General Kenobi.

Bien.

Si estas dos coincidencias nuestra puntuación de roca será 1. 0.

De acuerdo.

Puedes ver roca uno, roca dos roca el roca el algunos.

Será 1. 0.

Bien.

Y esto sólo se basa en la puntuación de F1.

Si mi frase mi la frase real un poco diferente.

Y esto es básicamente predicho por el modelo.

Si hubiera sido un poco diferente, nuestra puntuación de rock habría sido otra.

Bien.

Así que este tipo de comparación se hace básicamente bien.

Ahora calcularemos la métrica en el conjunto de datos de prueba.

Y sólo vamos a tomar los diez primeros registros.

Voy a utilizar la métrica de roca que hemos definido modelo de punto de entrenador.

Vamos a utilizar este lote tokenizer es igual a dos columnas de diálogo de texto y columna resumen uh columna resumen

derecho de este conjunto de datos en particular.

Entonces estamos leyendo las puntuaciones de cada nombre de perro y lo estamos mostrando por aquí.

De acuerdo.

Aquí podrá ver los datos que hemos generado.

Bien.

Podrás verlo.

De acuerdo.

Sólo calculamos las métricas de texto de cada diez para los datos de los diez primeros.

De acuerdo.

Así que aquí tienes mi puntuación de Pegasus no es nada.

Pero para Rogue One es tanto rock dos rock.

De lo contrario, es un muy menos porque la razón es muy simple, porque acabo de sintonía fina para 111 conjunto

de datos o una sintonía fina.

Sólo hemos hecho una época, por eso está ahí.

Pero más el valor viene hacia uno más mejor el uh métricas.

Bien, así es como básicamente se calculan las métricas.

Y aquí lo que estamos haciendo para cada métrica, para cada nombre de roca, básicamente vamos a calcular

la puntuación de acuerdo.

Ahora, interpretando lo bueno frente a lo malo, el rock puntúa cerca de uno.

Esto indica un fuerte solapamiento entre el resumen generado y el resumen de referencias, lo cual es deseable

en la tarea de resumen.

Bien, ahora puntúa entre 0. 7 y 0. 7 indica un solapamiento moderado.

Puntuación por debajo de 0. 5 es sugerir un mal partido.

Bien.

Pero aquí tenemos menos de 0. 5 porque sólo lo hemos entrenado durante una época.

De acuerdo.

Ahora, finalmente, vamos a seguir adelante y guardar el modelo.

Guardar modelo preentrenado.

También vamos a seguir adelante y guardar el tokenizer porque tanto esto vamos a utilizar específicamente en nuestro código.

De acuerdo.

Y una vez que lo guardemos también podrás cargarlo.

Usted sabe que puede cargarlo ver si probablemente ir por aquí.

Así que aquí está su modelo Pegasus derecho Config. json este este modelo punto guardar sentencias.

Y aquí están tus puntos de control junto con los recorridos que has hecho.

De acuerdo.

Toda la información está aquí.

Ahora lo que puedes hacer es que también puede cargar el tokenizer y uh, basado en algunos parámetros como lo que debería ser

su pena de longitud.

Como que tan grande si esto es mayor que uno uno.

Bien.

Uh, mira, para esto podemos configurar tres parámetros diferentes.

Una es la penalización por subrayado de longitud Número de bins y longitud máxima.

Longitud máxima.

Básicamente habla de como si yo quisiera probablemente crear un resumidor ¿verdad?

Para el máximo número de palabras probablemente debería crearlo yo o debería crearlo el modelo.

Penalización por subrayado de longitud.

Si el valor es mayor que uno, que básicamente significa que queremos una mayor longitud como tipo de cosa.

Ok, entonces voy a tomar el primer diálogo y el resumen ok.

Y luego intentamos crear nuestra tubería.

Así que para la tubería vamos a llamar a nuestro modelo.

Este es el modelo que ya hemos salvado.

Su modelo es igual al modelo Samsung de Pegasus y luego al tokenizador.

Bien.

Y aquí muestro mi prueba de muestra.

Aquí muestro mi referencia.

Y esto básicamente mi uh junto con este argumento en particular nos dará nuestro texto de resumen

que no es nada, pero es mi salida bien.

Así que una vez que ejecute esto, esto no es más que mi texto de resumen que mostrará la salida.

Así que aquí se puede ver la GPU de aceleración de hardware está disponible.

Su longitud máxima es así y así digamos que estos son la conversación que hemos hecho bien En mis datos, si probablemente

ir y ver Hana necesita resumen de referencia.

Este es el resumen de mi modelo.

De acuerdo.

Este es mi resumen de referencia.

Y este es mi modelo de resumen.

Estos son mis datos verdaderos.

Estos son mis datos generados a partir del modelo.

De acuerdo.

Así que espero que seas capaz de entender todos estos pasos.

Lo hemos ejecutado, lo cual es suficiente.

Y también hemos entrenado nuestro modelo.

Ahora rápidamente voy a ir por aquí y uh, voy a descargar esto, uh, descargar esto como mi archivo ipynb.

Y sólo voy a asegurarme de que seguir adelante y poner que dentro de mi código VS.

Y ahora, en el siguiente vídeo, nos centraremos en la aplicación de la solución integral.

De acuerdo.

Así que sí, esto era todo por mi parte.

Pero espero que te hayas hecho una idea de cómo utilizar probablemente un modelo específico a partir de la, eh, cara de abrazo

en sí.

Y esta es una forma genérica de utilizar cualquier modelo, en definitiva.

Así que sí, esto era todo por mi parte.

Nos vemos en el próximo vídeo.

Gracias, señor.
"""

# %%
data_ingestion_part_1 = """
Hola, chicos.

Así que vamos a continuar nuestra discusión con respecto a nuestro proyecto de extremo a extremo con la ayuda de Hugging

Face API.

Y ya hemos creado todo este cuaderno Jupyter en nuestra sesión anterior.

Uh, ahora lo que vamos a hacer es que, uh, ver, también hemos entrenado el modelo y vimos todos y cada uno

con respecto a los parámetros y todo.

Pero ahora mi objetivo final es convertir todo este cuaderno Jupyter en codificación modular, en un proyecto de principio

a fin.

De acuerdo.

Y en este vídeo hablaré de ello.

El primer paso será proceder a la ingesta de datos.

Y si ya has visto este era mi conjunto de datos ¿verdad?

Mi resumidor dash punto datos punto zip.

Así que el primer paso será que voy a tratar de extraer estos datos en particular, y luego voy a hacer los mismos

pasos.

Lo que básicamente se especifica aquí.

De todos modos, en primer lugar, lo que realmente necesita hacer es que sólo seguir adelante y descargar este archivo cuaderno Jupyter.

De acuerdo.

Descargue Ipynb y se descargará después de descargarlo.

Lo que he hecho es que he subido ya esto en mi carpeta de investigación.

Así que aquí si ves voy a cambiar el nombre de este resumidor de texto.

Bien, aquí podrás ver que tengo todo este archivo de cuaderno Jupyter y todos los pasos que probablemente hicimos

en la sesión anterior se mencionan aquí ahora, paso a paso, voy a tratar de mostrarte cómo puedes convertir

exactamente cómo puedes convertir todo este cuaderno Jupyter en una codificación modular donde implementamos

cosas como la ingestión de datos, uh, ya sabes, así que dentro de tus componentes verás que se creará la ingestión de datos, transformación

de datos, uh, y muchos más pasos a medida que avanzamos, desde el entrenador de modelos hasta

el despliegue de modelos.

Probablemente se creará todo, como la evaluación del modelo y todos los pasos.

De acuerdo.

Este es mi texto.

Resumidor.

Así que en primer lugar, lo que voy a hacer aquí es que voy a seguir adelante y actualizar mi readme.

Así que para este texto Summarizer utilizando abrazar la cara.

Bien, vamos a definir todos nuestros flujos de trabajo para automatizar toda la creación del proyecto.

Y recuerda que esto será completamente de punta a punta.

Ahora bien, estos flujos de trabajo será super importante porque veo que muchos, muchos de ustedes probablemente han creado proyectos con

la ayuda de Jupyter Notebook, pero nuestro objetivo principal es, básicamente, seguir adelante y

crear en una forma que será escalable en la producción.

¿Verdad?

Así que lo que haremos será intentar crear flujos de trabajo.

Y en este flujo de trabajo en particular vamos a definir algunos config YAML.

Vamos a definir componentes como la ingesta de datos y toda la transformación de datos modelo de formación modelo

de evaluación.

Y mientras se definen los flujos de trabajo lo que todas las cosas que tenemos que actualizar que también tratará

de entender bien, así que todo será discutido a medida que avanzamos.

Pero permítanme que les ponga en antecedentes.

Como lo que todas las cosas que vamos a, eh, empezar como cada vez que queremos definir cualquier módulo como la ingestión de datos, lo que todos los

componentes que realmente necesitamos para actualizar.

De acuerdo.

Así que en primer lugar tengo mi config punto YAML en este momento en el config punto YAML configuraciones básicas y todo lo que necesitamos

para actualizar.

Entonces tenemos este params punto YAML.

Siempre que hagamos bien el entrenamiento de nuestro modelo, probablemente tengamos que actualizar todos

los parámetros necesarios para nuestros modelos, ¿verdad?

Um cualquier parámetro hiperparámetro y.

De acuerdo.

En tercer lugar, eh, tenemos que crear probablemente nuestra propia entidad config.

Bien.

Hablaré de la importancia de configurar la entidad a medida que avancemos.

Entonces.

Uh, después de esto vamos a crear nuestro propio gestor de configuración.

De acuerdo.

Gestor de configuración y voy a hablar de por qué este gestor de configuración debe ser creado y lo que todas las cosas

que tenemos que actualizar en este gestor de configuración.

De acuerdo.

Así que eso es también lo que voy a discutir paso a paso.

Iremos definiendo todos y cada uno de los proyectos a medida que avancemos.

Entonces uh tenemos que seguir adelante y definir nuestros componentes.

Como he dicho uh tenemos que actualizar los componentes.

Ahora bien, estos componentes son lo que uh, como pasos o módulos como la ingestión de datos.

Ingesta de datos.

Transformación de datos.

Transformación de datos.

Entrenador modelo.

Bien.

Estos son algunos de los ejemplos de acuerdo.

Estos son algunos de los ejemplos con respecto a la actualización de los componentes.

A continuación, tenemos que crear nuestra tubería bien.

Crear nuestra tubería.

Ahora específicamente en pipeline lo que necesitamos crear es nuestro pipeline de entrenamiento y pipeline de predicción.

De acuerdo.

Así que esto es lo que probablemente vamos a seguir adelante y crear también.

Y lo haremos paso a paso para que puedas entenderlo bien.

Por último, lo que realmente tenemos que hacer es que después de crear nuestra tubería de formación o tubería de predicción, también

tenemos que asegurarnos de que creamos un front-end básico.

De acuerdo.

Así podremos crear APIs.

A partir de ahí podremos crear APIs de formación.

Y no solo eso, también podremos crear nuestras APIs de predicción por lotes ok.

Así que todas estas APIs tratarán de crearlo.

De acuerdo.

Así que sí, también podemos utilizar una pequeña aplicación frontal para poder ver esto.

De acuerdo.

Así que paso a paso lo iremos haciendo.

En este vídeo nos centraremos más en la parte de la ingestión de datos.

De acuerdo.

Así que la ingesta de datos es el primer componente que vamos a utilizar específicamente.

Ahora para que lo entiendas más o menos bien.

En primer lugar, intentaremos hacer toda la implementación en un cuaderno Jupyter.

A continuación, vamos a tratar de convertir eso en un. archivo py.

De acuerdo.

Así que en primer lugar aquí voy a seguir adelante y crear mi ingestión de datos.

Así que permítanme seguir adelante y escribir como un guión bajo datos guión bajo ingestión bien.

Punto p y n b.

Así que este es mi primer archivo que vamos a hacerlo.

Y aquí voy a seleccionar un núcleo.

Así que serán 3. 10.

Permítanme hacer una para que me acaba de seguir adelante y ejecutar el código y ver todo está funcionando bien.

Ahora lo que realmente voy a hacer es que voy a seguir adelante y crear un markdown, y esto será básicamente

mi proceso de Decisión de ingestión de datos o módulo de paso.

De acuerdo.

Ahora cada cada módulo que definimos probablemente tenemos que seguir el mismo proceso de acuerdo.

Uh como administrador de configuración uh params punto YAML config entidad y muchas cosas más.

Bien.

Así que en primer lugar voy a ir a mi ingestión de datos y permítanme seguir adelante y la importación de algunas de las

cosas como la importación de OS.

Y veamos cuál es mi directorio de trabajo actual.

De acuerdo.

Ahora aquí podrás ver en el directorio de trabajo actual estoy dentro de mi carpeta de investigación.

La razón es muy sencilla porque este archivo de ingestión de datos se crea básicamente en la carpeta de investigación.

Pero quiero empezar mi ejecución desde el nivel de mi proyecto que está fuera de esta carpeta de investigación.

Así que lo que voy a hacer, voy a seguir adelante y escribir OS punto chdir.

Uh, y voy a ir a mi directorio anterior, mi directorio padre.

Así que aquí, eh, con el fin de ir por aquí, voy a seguir adelante y escribir punto punto barra diagonal.

Bien.

Y ahora si sigo adelante y ejecutar mi PWD usted será capaz de ver que estoy dentro de mi Summarizer texto.

Ese es el directorio donde se crea mi proyecto.

Bien, este es el primer paso porque a partir de aquí necesito probablemente seguir adelante y comenzar mi ejecución.

Permítanme seguir adelante y hacer algunas células.

De acuerdo.

Ahora la primera cosa aquí es que vamos a seguir adelante y actualizar nuestra configuración. yaml.

Te voy a decir por qué, porque en el archivo readme también he escrito bien, Config. yaml.

Lo primero que tengo que actualizar es mi configuración. yaml.

Ahora dentro de este Config. yaml, ya sabes que tengo que proporcionar alguna información.

De acuerdo.

Qué tipo de información debo facilitar.

Mira, en primer lugar, recuerdas que cada módulo que definimos como la ingestión de datos es un módulo.

La ingesta de datos tomará algunos datos de entrada y creará algunos datos de salida.

Básicamente lo decimos como artefactos de acuerdo.

Podemos seguir adelante y crear carpetas.

Podemos crear algunos archivos CSV.

Probablemente también podamos seguir adelante y crear modelos.

Puede ser cualquier cosa como tal.

Bien.

Así que para cada módulo lo que tenemos que hacer es que tenemos que definir algunos config YAML.

De acuerdo.

Ahora en este config YAML, te proporciona la ruta del directorio de artefactos que necesita ser creado.

De acuerdo.

También puede ser que en la ingesta de datos, pueda estar requiriendo alguna URL de origen del conjunto de datos.

También se puede dar ese enlace.

Así que lo que voy a hacer es seguir adelante y en primer lugar crear mi carpeta raíz de artefactos.

De acuerdo.

Ahora esta carpeta raíz artefactos es mi derecho de salida de cualquier cualquier cualquier módulo de aquí.

De acuerdo.

Usted puede considerar que este es mi directorio raíz de la salida.

Así que probablemente quiero seguir adelante y escribirlo como artefactos.

De acuerdo.

A continuación, vamos a seguir adelante y definir nuestra ingestión de datos.

Así que esta es mi uh clave que realmente quiero definir para mi ingestión de datos.

Ahora mismo en mi ingestión de datos, lo que voy a hacer es que voy a seguir adelante y crear algunos crear algunas

rutas.

De acuerdo.

Por aquí, digamos que voy a seguir adelante y crear de esta manera.

Así que en primer lugar estoy creando dentro de mi carpeta de artefactos.

Digamos que si mi modelo de ingestión de datos está siendo, uh implementado, entonces probablemente debería seguir adelante y crear

una carpeta llamada como la ingestión de datos.

Bien.

Así que esto es básicamente dentro de la carpeta de artefactos.

Ahora en la ingestión de datos.

Ahora de lo que es nuestro principal objetivo.

Nuestro principal objetivo es leer el conjunto de datos o cargar el conjunto de datos desde donde viene.

Y esto es lo que es mi URL.

Directamente desde mi URL de GitHub que he dado en realidad.

¿Verdad?

Y si usted recuerda bien, si usted si usted simplemente recuerda aquí en mi texto Summarizer.

Bien.

Inicialmente lo que hicimos, leemos el conjunto de datos mediante el uso de este uh w obtener derecho si usted probablemente seguir

adelante y ver esto, uh, permítanme seguir adelante y mostrar.

De acuerdo.

Así que aquí se puede ver, a la derecha.

Estamos descargando y descomprimiendo el archivo desde alguna fuente.

Ya sabes, y este era mi enlace GitHub.

Así que de manera similar si quiero convertir esto, eh, en mi. py archivo, lo que realmente necesito hacer es que probablemente tengo

que seguir adelante y dar mi URL de origen.

Bien.

Aquí es donde probablemente vamos a cargar nuestro o.

Esta es la fuente de mi conjunto de datos que probablemente está llegando allí.

Luego, en la ingesta de datos, lo que realmente tengo que hacer, tengo que descargar el archivo zip y tengo que descomprimir.

Así que...

Así que el directorio unzip no es más que esta ubicación específica, correcto.

Y una vez que probablemente descargar el archivo zip donde tenemos que almacenarlo, debe ser almacenado dentro de una ingesta

de datos en forma de datos punto zip.

Así que debemos ser capaces de crear todas estas carpetas en particular una vez que estamos ejecutando la ingestión de datos

punto ipynb archivo.

De acuerdo.

Esto es muy importante.

Y esa es la razón por la que realmente necesitas escribir toda esta información en tu config. yaml, que no es nada, pero es

como un detalle de configuración de su archivo.

De acuerdo.

Ahora dentro de este cualquier campo que hemos definido ver directorio raíz.

Directorio raíz es sólo como una entrada que realmente tenemos que dar a la ingestión de datos diciendo que hey aquí

es donde mi carpeta tiene que ser creado, a la derecha.

Así que lo que probablemente puedo decir que el directorio raíz también puede ser considerado como una salida.

¿Verdad?

Así que cualquiera que sea la salida de mi ingestión de datos, será en primer lugar el directorio raíz.

Conoce el camino.

Pero dentro de esta ruta en particular vamos a crear todos estos archivos en particular.

Bien.

Y la URL de origen es, obviamente, una entrada porque aquí estamos dando el resumidor que dash datos punto

zip.

De acuerdo.

Para que sea capaz de extraer todos esos archivos en particular.

Así que, basándome en esto, volveré a mi ingestión de datos.

Y ahora en mi ingestión de datos, si realmente quiero leer todos estos archivos YAML.

Bien.

En primer lugar necesito crear campos para ellos.

Bien.

Porque aquí para cada campo hay unos valores.

Bien.

Así que con el fin de crear que los campos en particular voy a seguir adelante y crear mi clase de datos.

Así que de la clase de datos vamos a seguir adelante e importar mi clase de datos.

Y luego de Pathlib voy a seguir adelante y la ruta de importación.

Bien.

Así que la razón por la que estoy creando clases de datos porque entender los datos de entrada de salida a la derecha ya está definido por

aquí.

Estos son mis campos.

Esa será la salida dentro de mis artefactos.

Bien.

Así que con el fin de crear como lo que toda la salida de mi ingestión de datos va a dar, tengo que crear algunos campos.

Porque en ese campo sólo se retendrán esos valores.

Bien.

Así que aquí voy a seguir adelante y escribir clase de datos.

Y dentro de esta clase de datos voy a seguir adelante y crear mi clase que se llama como configuración de ingestión

de datos.

Ahora esta configuración de ingestión de datos tendrá dos detalles importantes correctos.

Dos categorías principales de información.

Cuál es la entrada del modelo y cuál debe ser la salida.

En este momento ya sabes cuál es la entrada y la salida.

No es nada.

Pero tengo que crear campos como directorio raíz.

Así que vamos a crearla.

Y sé que este directorio raíz debe ser de tipo de retorno de ruta derecha.

Debe ser de tipo path return.

De acuerdo.

Ahora, de forma similar, mi segundo campo no será más que la URL del guión bajo de origen.

Así que voy a seguir adelante y definir mi URL subrayado fuente.

Esto también debe ser una ruta de cómo asignar todos estos valores particulares.

Te lo mostraré porque necesitamos leer esta configuración. yaml en las etapas posteriores.

Ok entonces mi archivo local de datos underscore.

También debe ser de tipo ruta.

De acuerdo.

Y finalmente tienes este dir de underscore unzip.

Aquí voy a seguir adelante y el camino correcto.

Vale, pues ahora lo que he hecho en realidad, es asignar algunos.

He creado una clase de datos con todas estas variables particulares.

De acuerdo.

Ahora esto es lo que es mi configuración de ingestión de datos.

Y esto es básicamente considerado que hey esto puede ser mi entrada a mi módulo de ingestión de datos ok.

Y teniendo en cuenta esto donde la salida debe estar en este derecho variables particulares.

Porque automáticamente podrá crear ese tipo de carpetas ok.

Así que este fue mi segundo paso.

Esa es mi configuración.

Así que esa es la razón por la que incluso he escrito en mi archivo Léame que probablemente vamos a seguir adelante y actualizar nuestra

configuración. yaml.

De acuerdo.

Y esto para cada módulo tenemos que hacerlo bien.

Así que ahora vamos a seguir adelante y ejecutar esto.

Y ahora lo que realmente voy a hacer es que uh el siguiente paso será básicamente mi administrador de configuración.

Ver params punto YAML no es necesario porque no tengo ninguna entrada.

Este params dot YAML se actualizará sólo en el modelo de formación de esta entidad config se requerirá en algún

otro propósito.

Hablaré de eso también a medida que avancemos, pero nuestro gestor de configuración necesita ser actualizado.

¿Qué significa gestor de configuración?

Uh, verás que habrá algunas funcionalidades.

Definitivamente tenemos que escribir en todos los componentes que definimos, a la derecha.

Como en este, eh, mi objetivo principal es probablemente extraer el archivo zip, descomprimir el archivo zip zip, y almacenarlo en algún

tipo de carpetas dentro de la carpeta de artefactos.

Bien.

Así que eso es lo que probablemente vamos a escribir todas las funcionalidades en nuestro gestor de configuración config.

Ahora en primer lugar lo que realmente voy a hacer voy a seguir adelante y escribir de texto Summarizer punto constantes.

Así que debe ser fuente punto texto Summarizer bien.

Fuente punto texto Constantes del resumidor.

Voy a importar estrella bien.

Ahora voy a definir algunas constantes.

Además, hay otras dos funcionalidades comunes que ya hemos importado.

Una es leer subrayado YAML y otra es crear subrayado directorio.

Así que déjame hacer una cosa.

Déjame volver a mi carpeta de constantes.

Así que aquí dentro de mi fuente de acuerdo.

Hay algo como constantes bien.

Y voy a seguir adelante y abrir mi init punto pi bien.

Ahora por qué estoy abriendo esto porque necesito definir algunas de mis constantes.

¿Cuáles son las constantes que necesito?

Uno es mi archivo config punto YAML derecha.

Y un archivo YAML más que tengo no es más que mi archivo params dot YAML, ¿verdad?

Así que estas dos constantes que definitivamente requieren para que yo consiga la ruta de esta configuración. yaml y ruta punto YAML derecho params punto YAML

porque necesito tener la información dentro de este derecho?

Probablemente tengo que leer toda la información dentro de este derecho.

Así que seguiré adelante y escribiré desde Pathlib import path.

Bien, entonces tengo mi ruta de archivo de configuración.

Así que permítanme seguir adelante y definir mi ruta de archivo de configuración es igual a.

Y voy a definir mi ruta de carpeta de ruta.

Y permítanme seguir adelante y escribir config.

Dash config punto YAML.

Ok así que voy a ir y leer mi config YAML aquí.

Y básicamente voy a obtener la ruta de esta configuración YAML.

Así que eso es lo que estoy definiendo en estas dos constantes.

Y recuerda siempre que las constantes deben definirse en mayúsculas.

Siempre es una buena práctica que, cuando realizamos un proyecto de principio a fin, sigamos lo que se sigue básicamente

en el sector, ¿verdad?

Así que esto será básicamente en mayúsculas.

Y definitivamente requerimos configuración. yaml y params dot YAML antes de implementar cualquier módulo de ingestión de datos.

De acuerdo.

Esto es lo que he hecho.

Y luego uh de nuevo de SK punto de texto Summarizer también he importado leer YAML y crear directorios, que son mis dos diferentes

funcionalidades comunes que vamos a utilizar específicamente.

Bien, una vez hecho esto, seguiremos adelante y definiremos nuestro gestor de configuración.

Así que ahora voy a seguir adelante y crear mi clase Gestor de configuración Bien, ahora este gestor de configuración tendrá

¿qué?

Toda la información.

Seguiré adelante y crearé mi definición en él.

Subrayado subrayado.

De acuerdo.

Ahora dentro de esto, uh.

Dentro de este init lo que todos los parámetros que necesito para proporcionar uno es el yo.

De acuerdo.

El segundo es básicamente mi ruta de configuración de subrayado.

Debido a que la ruta config que necesitamos para leer de antemano mediante la ejecución antes de cada modelo se ejecuta.

Bien.

Así que básicamente se asignará en mi ruta de archivo de configuración que hemos creado dentro de constantes.

Entonces coma tendré mi.

Params underscore file path okay es igual a params file path okay.

Así que también requieren mi ruta de archivo params bien.

Así que esta dos información de antemano que necesito antes de empezar cualquier módulo de acuerdo.

Ejecución de cualquier módulo.

Ahora una vez que tenemos todas estas cosas, entonces voy a seguir adelante y asignar auto punto config es igual a.

Tenemos que leer escribir lo que realmente necesitamos para leer el archivo de configuración YAML.

Bien.

Así que aquí con el fin de leer esto, usted sabe que yo ya he creado una función que se llama como leer YAML.

Así que aquí voy a seguir adelante y escribir leer subrayado YAML.

Y aquí voy a seguir adelante y definir mi config underscore ruta de archivo de acuerdo.

O simplemente seguiré adelante y escribiré esta ruta de archivo en particular.

Así que básicamente estamos leyendo de este archivo en particular ok este es uno.

Entonces seguiremos adelante y escribiremos self dot params.

Self dot params es igual a read YAML.

Y dentro de esta lectura YAML vamos a dar mi ruta de archivo params.

Ok perfecto hemos leido esto uno es la ruta del archivo config y otro es la ruta del archivo params.

De acuerdo.

Y luego ver.

Esta es la información básica que básicamente requerimos inicialmente antes de empezar cualquier módulo.

De acuerdo.

Ahora lo que podemos hacer es que en primer lugar tenemos que empezar a crear el directorio.

Ahora lo que son los directorios que realmente necesito para crear.

Uno es mi artefacto raíz y luego uno es mi directorio raíz derecha.

Así que este directorio dos definitivamente tenemos que seguir adelante y crearlo.

Así que aquí voy a seguir adelante y escribir crear directorios.

Y aquí voy a seguir adelante y dar mi auto punto porque tenemos que dar la información del directorio.

En primer lugar tenemos que crear el artefacto raíz derecha.

Así que aquí voy a escribir self punto config punto artefactos.

Permítanme copiarlo de aquí.

Este campo específico llamado artefactos subrayado raíz bien.

Así que esto es lo que estamos haciendo.

Tenemos en primer lugar la creación del directorio raíz del artefacto bien.

Ahora perfecto.

Este es mi paso inicial dentro de mi constructor.

Tan pronto como inicializamos el administrador de configuración mi directorio raíz de artefactos necesita ser creado bien.

Y si recuerdas que hemos creado esta función en particular en nuestras funcionalidades comunes, ¿verdad?

Entonces lo que voy a hacer, voy a seguir adelante y escribir mi una función, obtener config ingestión de datos, porque tenemos que leer

toda la configuración que hemos especificado en relación con la ingestión de datos.

Y este tipo de retorno no será otra cosa que la configuración de ingestión de datos.

¿Verdad?

Así que lo que ahora estoy haciendo es que mediante el uso de esta función en particular voy a leer toda esta información

específica.

De acuerdo.

Y entonces toda esta información necesita ser asignada a la configuración de ingesta de datos que hemos definido

aquí.

Y así es como básicamente escribimos un código en Industry Gate.

E inicialmente lo estoy haciendo en Jupyter notebook.

Más adelante convertiré esto en. py, y te mostraré cómo puedes hacerlo con la ayuda

de clases.

Bien, ahora lo que realmente voy a hacer, voy a seguir adelante y escribir.

Config es igual a self dot config dot data cell dot config dot data underscore ingestion.

Así que en resumen lo que estoy haciendo es que estoy leyendo estos datos en la ingestión de puntos por aquí.

Bien.

Estoy leyendo esto y esto básicamente se asignarán todos los valores dentro de la configuración.

De acuerdo.

Y luego voy a seguir adelante y crear los directorios.

Y aquí voy a seguir adelante y escribir config punto raíz guión bajo dir.

Vale, perfecto.

Así que esto está hecho.

Y aquí voy a seguir adelante y escribir la ingestión de datos dot config.

Ahora devolveré todos los valores dentro de mi configuración de ingestión de datos.

De acuerdo.

Y sabemos que todos los valores que son capaces de leer desde el archivo de configuración.

De acuerdo.

Porque ya hemos asignado este derecho en mi auto punto config punto ingestión de datos que ya hemos

leído por aquí.

Esta ingesta de datos la estamos asignando en esta configuración particular.

De acuerdo.

Y luego voy a seguir adelante y asignar los valores de aquí.

Así que voy a seguir adelante y escribir mi guión bajo raíz.

Dir es mi primera.

Voy a seguir adelante y escribir config punto dir raíz.

Así que estoy leyendo todos los valores del archivo de configuración y voy a asignar esos valores dentro

de mi config ingestión de datos en sí, entonces mi URL subrayado fuente no es más que config punto URL subrayado fuente.

Entonces seguiré adelante y escribiré coma aquí.

A continuación, voy a escribir los datos de subrayado local.

Underscore file es igual a config dot local underscore data underscore file.

Entonces tengo mi unzip guión bajo dir es igual a config punto unzip guión bajo dir.

De acuerdo.

Así que todos estos valores particulares están aquí.

Así que déjame seguir adelante y comprobarlo.

Si todo lo que la ortografía es correcta o no con respecto a la raíz underscore fuente underscore URL

local underscore datos underscore archivo y descomprimir underscore dir.

Así que mira esto parece perfecto.

Y esto con esta información soy capaz de asignar todos estos valores particulares a mi configuración de ingestión de datos.

Y esta es la entrada que probablemente irá a mi, uh, componente de ingestión de datos.

De acuerdo.

Así que aquí lo que voy a hacer voy a devolver esto.

Devuelve esta configuración de ingestión de datos.

De acuerdo.

Así que hemos ejecutado este uh así que esto es lo que es mi gestor de configuración que básicamente se está actualizando.

Ahora lo que voy a hacer es seguir adelante e importar.

Import os import url lib.

Voy a hablar de ello porque el siguiente paso que vamos a hacer es que vamos a implementar todo nuestro

componente de ingestión de datos.

De acuerdo.

Así que aquí uh lo siento URL lib.

De acuerdo.

Usted es un punto lib solicitud como solicitud.

A continuación, vamos a importar el archivo zip.

Luego desde saucy punto from src punto text Summarizer punto logging voy a importar también

logger y luego desde source punto text summarizer punto utils punto common import.

Vale, no lo haré.

De acuerdo.

Está bien.

Y esta cantidad de biblioteca será más que suficiente porque ahora vamos a actualizar nuestros componentes a la derecha.

Así que vamos a seguir adelante y actualizar nuestros componentes aquí.

Y ya está aquí lo que hemos hecho realmente.

Si te acuerdas yo también iré escribiendo algunas cosas.

Estas son mis actualizaciones de configuración.

Para las actualizaciones de configuración básicamente puedo seguir adelante y escribir esto porque estos son los pasos que realmente

tenemos que seguir.

Y esto es lo que es mi configuración de ingestión de datos.

Así que aquí voy a seguir adelante y escribir mi configuración básica que se requiere bien Basic.

Configuración básica.

De acuerdo.

Esto es perfecto.

Mi actualización de configuración está hecha.

Esto está hecho.

Y ahora voy a seguir adelante y definir mis componentes.

Ahora con el fin de definir los componentes lo que realmente necesito hacer probablemente necesito seguir adelante y crear

una clase.

Así que voy a seguir adelante y escribir la ingestión de datos.

Será mi clase.

Ahora después de crear mi ingesta de datos voy a seguir adelante y escribir definición init guión bajo

auto coma config que será de tipo ingesta de datos config.

Porque esta configuración la necesitamos inicialmente para poder ejecutar mi configuración de ingestión de datos.

Así que aquí voy a seguir adelante y escribir auto punto config es igual a cualquier config que he definido en realidad

por aquí.

En este momento voy a crear una función descargar todos los archivos que queremos.

Así que archivo de descarga de definición.

Y aquí voy a usar mi propia palabra clave.

Bueno, así que permítanme seguir adelante y, probablemente, uh, uh, poner una condición, ver cómo mi nombre es que cualquier archivo zip o lo que sea esta

ruta que hemos dado para el archivo zip, tenemos que extraer probablemente esto.

Y tenemos que descomprimir en esta carpeta en particular al descargar el zip.

Probablemente necesitamos poner esto en esta carpeta en particular ok.

Así que aquí en primer lugar voy a escribir una condición de acuerdo.

Mira esto bien.

Esta será una condición muy importante si no punto punto punto punto existe.

Si ese archivo de datos local en particular no existe, entonces probablemente siga adelante y utilice esta URL de punto de

solicitud.

Recuperar y dar la URL por aquí y dar el nombre del archivo por aquí.

De acuerdo.

El nombre del archivo será este archivo de datos local.

Y esto es básicamente su URL de origen.

Podrás obtener cabeceras de comas de nombres de archivo sin problemas.

Si no, simplemente pondré otro logger diciendo que Logger. información.

Digamos que voy a seguir adelante y escribir una condición F archivo ya existe bien.

Ya existe de otro modo.

Aquí podemos seguir adelante y escribir logger. información.

Y aquí voy a seguir adelante y escribir diciendo f archivo de cadena se descarga.

De acuerdo.

Y también podrás ver la carpeta de artefactos.

Así que una vez que esto se hace bien.

Así que esta es una de las funcionalidades que necesito hacer.

La otra funcionalidad que realmente necesito hacer es mi extraer el archivo zip.

Bien.

Así que cualquiera que sea el archivo zip básicamente descargado tenemos que extraerlo.

Ahora para extraerlo tenemos otra funcionalidad y debe ser creada dentro de su componente de ingestión

de datos.

Eso no es más que extraer el archivo zip.

Así que aquí estoy usando auto punto unzip punto unzip directorio.

En primer lugar me quedo con esta información.

Voy a escribir os dot make directory unzip path exist underscore true.

A continuación, con la ayuda de archivo zip punto archivo zip, vamos a tratar de extraer toda esta información en particular sobre

que a partir de esa ruta unzip particular.

De acuerdo.

Así que esta es mi otra funcionalidad que realmente tenemos que seguir adelante y escribir dentro de nuestro componente.

De acuerdo.

Ahora vamos a seguir adelante y ejecutar esto.

Así que en primer lugar lo que voy a hacer voy a seguir adelante y escribir mi config y voy a inicializar a mi administrador de configuración.

De acuerdo.

Entonces uh voy a seguir adelante y definir mi configuración de ingestión de datos porque necesito leer esto y voy a inicializar mi configuración

de ingestión de datos.

De acuerdo.

Uh para inicializar la configuración de ingestión de datos de antemano.

Bueno voy a seguir adelante y escribir config punto uh obtener la ingestión de datos.

Y esta función ya está definida dentro de mi gestor de configuración.

En este momento lo que realmente voy a hacer y recordar este tipo de retorno siempre será una configuración de ingestión de

datos.

De acuerdo.

Y luego voy a seguir adelante y definir mi ingestión de datos que será mi componente que voy a inicializar

por aquí.

Y aquí mi config se asignará a cualquiera que sea la configuración de ingestión de datos que he conseguido desde aquí.

De acuerdo.

Y, finalmente, puedo seguir adelante y escribir la ingestión de datos dot dos funciones que he definido.

Uno es el archivo de descarga y luego la ingestión de datos punto descomprimir derecha.

Extraiga el archivo zip.

Así que esta funcionalidad es la que he definido aquí.

Bien.

Así que inicialmente lo que hicimos fue inicializar el gestor de configuración.

Luego llamamos a esta función en particular que probablemente está devolviendo el tipo es la configuración de ingestión de datos.

E internamente podrás ver que estamos leyendo esto.

Y en el inicializador de la derecha es la lectura de la configuración de YAML y params ruta del archivo punto.

Bien.

Y finalmente podrás ver que estamos extrayendo esto.

Ahora déjame hacer una cosa.

Déjame ejecutar esto ahora mismo.

Puedes ver que no tengo ninguna carpeta de artefactos, ¿verdad?

No tengo.

Así que vamos a ejecutar y ver si esto se ejecutará.

Aquí puede ver que el archivo YAML está vacío.

Así que ahora mismo mi params YAML está vacío.

Así que permítanme seguir adelante y escribir clave de dos puntos valor de acuerdo.

Inicialmente no debe estar vacío bien.

Pero actualizaremos esto más adelante en la Config. yaml está ahí.

Así que hagamos una cosa.

Vamos a ejecutarlo bien.

Así que ahora uh, params esperados punto YAML.

De acuerdo.

Oh, vale, vale.

Lo siento, lo siento, lo siento.

Llave.

Debería ser así.

En forma de pares clave-valor.

Ahora si sigo adelante y lo ejecuto.

Así que aquí se puede ver que todo está creado.

Pero estoy recibiendo un error.

Logger no tiene ningún atributo en inc.

No.

¿Qué es eso?

Creo que hay un pequeño error tipográfico.

Veamos cuál es el camino.

De acuerdo.

Debería ser información que he escrito.

Ignora algo.

Así que las actualizaciones de configuración.

Creo que debería estar en algún sitio donde esté bien.

Aquí logger. información.

Bien, lo ejecutaré.

Ahora vamos a ejecutarlo de nuevo.

Aquí puede ver que el archivo ya existe porque fue descargado previamente.

Y tenemos el error por aquí, ¿verdad?

Pero si usted sigue adelante y ver en mi carpeta de artefactos, aquí está mi conjunto de datos de Samsung que mi tren de prueba de validación

conjunto de datos.

Junto con eso tienes este zip de datos.

Junto con eso también tiene su archivo CSV derecha.

También puedes ver tu archivo CSV, tu prueba de entrenamiento y validación.

Así que en resumen, lo que hemos hecho es que hemos implementado la ingestión de datos, en la que nuestro

objetivo principal era probablemente leerlo de una fuente, descargar un archivo zip y extraer ese archivo zip y guardarlo en una carpeta dentro

de la ingestión de datos.

Aquí también podrás ver la configuración. yaml o lo siento el artefacto barra de ingestión de datos.

Tienes los datos punto zip.

Esto se descargó inicialmente.

Entonces cuando lo extrajimos obtuve esta carpeta en particular junto con este test punto csv train punto csv

y validation punto CSV.

Así que nuestra parte de ingestión de datos está hecha.

Ahora lo que haré en el próximo video iremos a la parte dos donde convertiremos todo este código

en un código modular.

De acuerdo.

Eso es lo que veremos en el próximo vídeo.

Así que espero que les guste este vídeo en particular.

Nos vemos en el próximo vídeo.

Gracias.
"""

# %%
data_ingestion_part_2 = """
Hola, chicos.

Así que vamos a continuar el debate con respecto a la ingestión de datos.

Ya en la primera parte, hemos diseñado todo este cuaderno Jupyter en el que ejecutamos paso

a paso.

Y lo que era nuestro objetivo para obtener probablemente la carpeta de artefactos, somos capaces de obtener la carpeta

de artefactos en este momento.

En mi siguiente paso, lo que realmente voy a hacer es que voy a tratar de convertir todo el archivo de cuaderno Jupyter en codificación

modular mediante el uso de este. archivo py.

Bien, ahora recuerden que voy a usar los mismos pasos que recuerdan aquí.

Como veis por aquí, lo primero es que tenemos que actualizar esta config. yaml.

¿Verdad?

Así que si abro mi archivo readme, el primer paso es básicamente actualizar la configuración. yaml.

Así que esto ya está hecho.

Así que no tengo que hacer nada aquí.

Luego vamos y actualizamos params dot YAML.

Así que ahora mismo params dot YAML no es necesario en la ingestión de datos.

Ahora vamos a seguir adelante y actualizar mi entidad config.

Ahora esto es realmente importante con respecto a la entidad config.

Qué es exactamente lo que viene bien.

Así que si probablemente voy a mi entidad config.

Así que aquí podrás ver Vamos a abrir mi fuente y vamos a abrir mi entidad.

Bien.

Así que dentro de mi entidad hay algo llamado como init underscore py.

O bien puede crear un archivo más como config_entity. py.

Si no, puedes utilizarlo directamente.

Ahora dentro de mi entidad config.

Lo siento.

Dentro de mi esta entidad.

Lo primero que necesito crear es mi clase de datos.

Bien.

Así que voy a seguir adelante y copiar esto, y voy a seguir adelante y pegarlo aquí.

Bien.

Así que este es el primer paso que realmente tenemos que hacerlo eh, es con respecto a nuestra entidad.

Bien.

Por otra parte, si vuelvo a mi archivo Léame, el siguiente paso es que tengo que actualizar mi gestor de configuración.

Ahora, para actualizar el gestor de configuración tengo que ir a este config.

Y hay algo que se llama configuración. py.

Y si ya has visto esta configuración. py aquí podrá comprobarlo.

Sólo tengo que asegurarme de que voy a ir a mi ingestión de datos.

Actualizaré estas dos bibliotecas por ahí.

Esta es mi configuración. py.

Así que déjame guardar esto.

Y luego si voy a mi uh lo siento siguiente paso.

Así que esto no es más que mi gestor de configuración.

Así que aquí voy a copiar esto por completo y voy a actualizar esto en mi por aquí.

Bien.

Y aquí es, básicamente, me pregunta por la configuración de la ingestión de datos en este momento la ingestión de datos ya sabes donde está

disponible.

Así que aquí voy a seguir adelante y escribir desde src punto de texto Summarizer.

Uh, ingestión de datos punto básicamente significa que es básicamente presente en mi entidad.

Así que la importación de datos de configuración de ingestión bien.

Así que ahora, básicamente, seguir adelante y siguió adelante y creado dentro de esta carpeta en particular en sí.

Bien.

Así que esta es mi ingesta de datos.

Así que este paso también se hace.

Ahora si vuelvo al siguiente paso ahora necesito implementar mis componentes.

Ahora para implementar mis componentes necesito seguir adelante y actualizar esta librería.

Así que déjame ir por aquí.

Y con el fin de crear los componentes voy a seguir adelante y crear dentro de mi carpeta de componentes.

Así que aquí voy a crear un archivo de datos de un guión.

De acuerdo.

Así que voy a seguir este nombre.

La misma convención de nomenclatura está bien.

Así que déjame hacer una cosa.

Permítanme renombrar esto y escribiré data underscore ingestion dot p y.

De acuerdo.

Y copiaré esto aquí por completo.

Y después de copiar esto voy a copiar todo el código de esta clase.

De acuerdo.

Este es todo el código de mi clase.

Lo copiaré aquí.

Bien.

Porque aquí tengo dos funcionalidades.

Uno es el archivo de descarga y el otro es el archivo de extracción.

Pero me sigue pidiendo la ingestión de datos por aquí.

Así que uh de nuevo tenemos que importar esto de donde tenemos que importar esto de la uh.

Así que aquí voy a escribir desde src punto texto Summarizer punto entidad.

Voy a seguir adelante e importar mi configuración de ingestión de datos.

Así que esto está hecho.

Así que esta es también mi funcionalidad que se completa.

Y si probablemente seguir adelante y ver mi archivo Readme mismos pasos como administrador de configuración a continuación, actualizar los

componentes.

Por último, creamos nuestra canalización.

Ahora vamos a crear la tubería uh.

Lo que voy a hacer es que voy a, eh, voy a ir a mi carpeta de tuberías.

De acuerdo.

Y aquí dentro de mi carpeta de tuberías, lo que voy a hacer es que voy a crear mi primera etapa.

De acuerdo.

Así que aquí vamos a seguir adelante y crear mi primera etapa voy a escribir etapa guión bajo uno guión

bajo datos guión bajo ingestión punto o voy a escribir datos ingestion_pipeline. py está bien.

Así que esta es mi primera etapa.

Uh con el fin de crear la etapa uno voy a volver a mi.

Sólo un segundo voy a cerrar este archivo readme params punto init.

No lo requiero.

Déjame hacer una cosa.

Permítanme abrir mi punto de ingestión de datos ipynb.

Y aquí usted será capaz de ver que sólo tengo que seguir adelante y ejecutar este derecho.

Esta, esta es la parte que voy a ejecutar ahora mismo antes de seguir adelante y ejecutarlo.

Lo que voy a hacer es que en primer lugar, sólo voy a seguir adelante y carga de resumen de texto lo siento

de src punto de texto Summarizer.

De acuerdo.

Dot config uh, dot configuration Voy a seguir adelante e importar mi gestor de configuración

junto con esto desde src dot text Summarizer dot components.

Componentes de punto ingestión de datos de punto.

Voy a seguir adelante e importar.

Importación de datos.

Bueno, entonces de texto Summarizer punto de registro sólo voy a seguir adelante e importar mi registrador.

De acuerdo.

Ahora lo que voy a hacer ya que estamos creando un canal de formación, voy a seguir adelante y crear

mi canal de formación de ingestión de datos de clase.

De acuerdo.

Definición.

Subrayado.

Underscore init.

Subrayado.

Subrayado.

Uno mismo.

De acuerdo.

Esto será básicamente mi auto palabra clave.

Y aquí sólo voy a seguir adelante y sólo decir pasar porque no tengo no quiero inicializar

nada en sí.

Pero aquí voy a seguir adelante y crear una definición de función.

Iniciar la ingestión de datos de subrayado.

De acuerdo.

Y aquí voy a usar mi propia palabra clave.

Ahora dentro del yo lo que realmente voy a hacer, el mismo código que he escrito por aquí sólo tratará

de ejecutarlo.

De acuerdo.

Así que aquí está todo lo mío.

Así que usted será capaz de ver esta configuración esto esto como la ingestión de datos que hemos inicializado.

Entonces usted tiene su archivo de descarga y extraer el archivo zip.

De acuerdo.

Así que una vez que esto se ejecuta automáticamente esto probablemente debería seguir adelante y crear una carpeta de artefactos.

Así que esta es mi línea de entrenamiento.

Ahora de nuevo si sigo adelante y abro mi archivo Readme después de crear un pipeline de entrenamiento.

Bien.

También tengo que asegurarme de que probaremos si todo funciona bien o no.

Bien, ahora para probarlo, si recuerdas, también creé un Main. py donde estábamos probando inicialmente la parte

de registro también.

Ok, entonces uh, junto con esto, dejame hacer una cosa.

Voy a seguir adelante y escribir desde src punto de texto Summarizer.

Tubería de puntos.

Canal de ingesta de datos de la primera fase.

Voy a seguir adelante e importar el pipeline de entrenamiento de ingestión de datos.

De acuerdo.

Así que vamos a utilizar un escribir uno por uno.

Como cada módulo será probablemente creado.

Así que todo el proceso de formación se creará aquí mismo.

Así que nombre de subrayado etapa voy a definir una constante.

Y voy a decir hey esta es mi etapa de ingestión de datos ok.

Y luego vamos a seguir adelante y utilizar un bloque try catch.

leñador. información.

Y aquí voy a usar mi cadena f.

Básicamente me limitaré a escribir.

Este es mi nombre de subrayado de escenario ok.

Uh iniciado bien iniciado.

Y entonces voy a seguir adelante y escribir mi ingestión de datos, datos de ingestión variable de ingestión de datos Pipeline

bien es igual a.

Voy a seguir adelante e inicializar mi canal de formación de ingestión de datos.

De acuerdo.

A continuación, voy a seguir adelante y escribir la ingestión de datos.

La ingesta de datos subraya el punto de inicio del proceso de formación.

Bien.

Lo siento.

Debería serlo.

El proceso de ingestión de datos es Dot.

Iniciar la ingesta de datos.

Y aquí vamos a inicializarlo.

Y luego ingestión ingestión pipeline Estoy recibiendo un error por aquí.

La declaración debe ir separada por una nueva línea.

Algo es el problema logger punto esta bien.

Así que aquí había utilizado este bien no se preocupe.

Y por último voy a seguir adelante y escribir logger. información.

Y aquí permítanme escribir una etapa de cuerda.

Cualquiera que sea el nombre artístico Stage.

Nombre artístico.

Y aquí.

Escenario.

Bien, usaré una cuerda F.

De acuerdo.

Completado.

De acuerdo.

Hecho.

Y esta será mi excepción.

Excepción.

Salvo excepción como E.

Y luego voy a seguir adelante y escribir logger punto de excepción.

También puedo seguir adelante y plantear esta e.

Y aquí voy a seguir adelante y escribir aumento e.

De acuerdo.

Así que esto es lo que es mi ingestión de datos.

Ahora lo que puedo hacer es que puedo seguir adelante y ejecutar esto.

Así que con el fin de ejecutarlo, en primer lugar lo que voy a hacer, voy a seguir adelante y eliminar mi carpeta

de artefactos y sólo ver si todo va a funcionar bien o no en esto.

De acuerdo.

Así que voy a ir a mi símbolo del sistema.

Estaré dentro de mi V y V.

Puedo seguir adelante y escribir Python principal punto py bien.

No.

Nombre del módulo.

Resumidor de textos.

¿De qué se trata?

Uh, veamos esta línea en particular donde está en la etapa uno de ingestión de datos.

Así que aquí voy a escribir src punto.

De acuerdo.

Ahora creo que debería funcionar.

Limpiar la pantalla python main. py.

Y aquí puedes ver que tu archivo se ha descargado.

Se ha completado la ingestión de datos por etapas.

Y si sigo adelante y veo esto esto se ve bien.

Y también se crea tu carpeta de artefactos.

Así que espero que les guste este vídeo en particular.

Espero que entiendas lo que es la ingestión de datos.

Ahora lo que voy a hacer, voy a seguir adelante y añadir todos los archivos.

Bien, voy a confirmar todos los archivos.

Diré git commit menos m ingestión de datos completada.

De acuerdo.

Y git push Origen para significar bien.

Hecho.

Así que espero que seas capaz de entender esto.

Espero que la comisión también sea básicamente sucedido.

Si también quieres probablemente verificarlo, creo que deberías poder conseguirlo por aquí.

Voy a recargar con respecto al texto, Summarizer y uh, artefactos no vendrá por aquí, pero los registros

está llegando.

Probablemente tenga que borrar este logs también porque no quiero logs por aquí.

Pero junto con esto, si voy y veo dentro de mi fuente y componentes, mi ingestión de datos necesita ser

ya está actualizado, ¿verdad?

Así que espero que sean capaces de entender este vídeo en particular.

En el próximo video, voy a seguir adelante con uh, el siguiente importante, uh, módulo que no es más que la transformación

de datos.

Y de nuevo, intentaremos convertirnos de nuevo.

Este cuaderno Jupyter será mi referencia para hacer todo como hicimos la ingesta de datos.

Del mismo modo, vamos a seguir adelante y hacer la transformación de datos.

Y la transformación de datos tiene muchos muchos pasos.

Así que sí, os veré a todos en el próximo vídeo.

Gracias, señor.
"""
